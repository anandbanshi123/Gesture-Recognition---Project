# %% [markdown]
# # Gesture Recognition
# In this project, we are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Import libraries to get started.

# %%
import numpy as np
import datetime
import os
import cv2

import random as rn
import tensorflow as tf
from keras import backend as K

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam

from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization
from keras.layers import Activation, Dropout, ZeroPadding3D
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Conv3D, MaxPooling3D
from tensorflow.keras.layers import LSTM, GRU

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
rn.seed(30)
tf.random.set_seed(30)

train_path = './Project_data/train'
val_path = './Project_data/val'
train_doc = np.random.permutation(open(f'Project_data/train.csv').readlines())
val_doc = np.random.permutation(open(f'Project_data/val.csv').readlines())

# %% [markdown]
# ## Generator Class
# This is one of the most important part of the code. The overall structure of the generator is broken down into modules. In the generator, we are going to preprocess the images as we have images of 2 different dimensions as well as create a batch of video frames.

# %%
total_frames = 30
num_frames = 15
gestures = 5
image_height = 100
image_width = 100
img_idx = np.round(np.linspace(0, total_frames-1, num_frames)).astype(int)

# %%
from skimage.io import imread
from skimage.transform import resize

def resize_crop_image(image):
    if image.shape[0] > 120 and image.shape[1] > 120:
        image = resize(image, (120, 120))
        
    height = image.shape[0]
    width = image.shape[1]
    height_center = height//2
    width_center = width//2
    image = image[(height_center-60):(height_center+70), (width_center-50):(width_center+70)]
    image = resize(image,(image_height, image_width))
    return image

# %% [markdown]
# Let's test the function resize_crop_image by writing a test function

# %%
from matplotlib import pyplot as plt

def show_resize_crop_image(paths):

    for index, path in enumerate(paths):
        plt.figure(figsize=(20,20))
            
        plt.subplot(5, 2, index*2+1)
        image = resize_crop_image(imread(path))
        plt.imshow(image)
        plt.title('Modified')
        
        plt.subplot(5, 2, index*2+2)
        plt.imshow(imread(path))
        plt.title('Original')
                
    plt.show()

# %%
paths = ["Project_data/train/WIN_20180907_15_35_09_Pro_Right Swipe_new/WIN_20180907_15_35_09_Pro_00012.png",
        "Project_data/train/WIN_20180907_15_35_09_Pro_Right Swipe_new/WIN_20180907_15_35_09_Pro_00014.png",
        "Project_data/train/WIN_20180907_15_35_09_Pro_Right Swipe_new/WIN_20180907_15_35_09_Pro_00018.png",
        "Project_data/train/WIN_20180907_15_43_28_Pro_Right Swipe_new/WIN_20180907_15_43_28_Pro_00013.png"]

show_resize_crop_image(paths)

# %%
class DataGenerator:
    def __init__(self, width=120, height=120, frames=30, channel=3, 
                 crop = True, normalize = False, affine = False, flip = False, edge = False  ):
        self.width = width   # X dimension of the image
        self.height = height # Y dimesnion of the image
        self.frames = frames # length/depth of the video frames
        self.channel = channel # number of channels in images 3 for color(RGB) and 1 for Gray  
        self.affine = affine # augment data with affine transform of the image
        self.flip = flip
        self.normalize =  normalize
        self.edge = edge # edge detection
        self.crop = crop

    # Helper function to generate a random affine transform on the image
    def __get_random_affine(self): # private method
        dx, dy = np.random.randint(-1.7, 1.8, 2)
        M = np.float32([[1, 0, dx], [0, 1, dy]])
        return M

    # Helper function to initialize all the batch image data and labels
    def __init_batch_data(self, batch_size): # private method
        batch_data = np.zeros((batch_size, self.frames, self.width, self.height, self.channel)) 
        batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
        return batch_data, batch_labels

    def __load_batch_images(self, source_path, folder_list, batch_num, batch_size, t): # private method
    
        batch_data,batch_labels = self.__init_batch_data(batch_size)
        # We will also build a agumented batch data
        if self.affine:
            batch_data_aug,batch_labels_aug = self.__init_batch_data(batch_size)
        if self.flip:
            batch_data_flip,batch_labels_flip = self.__init_batch_data(batch_size)

        #create a list of image numbers you want to use for a particular video
        img_idx = [x for x in range(0, self.frames)] 

        for folder in range(batch_size): # iterate over the batch_size
            # read all the images in the folder
            imgs = sorted(os.listdir(source_path+'/'+ t[folder + (batch_num*batch_size)].split(';')[0])) 
            # Generate a random affine to be used in image transformation for buidling agumented data set
            M = self.__get_random_affine()
            
            #  Iterate over the frames/images of a folder to read them in
            for idx, item in enumerate(img_idx): 
                image = cv2.imread(source_path+'/'+ t[folder + (batch_num*batch_size)].strip().split(';')[0]+'/'+imgs[item], cv2.IMREAD_COLOR)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                
                #crop the images and resize them. Note that the images are of 2 different shape 
                #and the conv3D will throw error if the inputs in a batch have different shapes  
                if self.crop:
                    image = self.__crop(image)
                # If normalize is set normalize the image else use the raw image.
                if self.normalize:
                    resized = self.__normalize(self.__resize(image))
                else:
                    resized = self.__resize(image)
                # If the input is edge detected image then use the sobelx, sobely and laplacian as 3 channel of the edge detected image
                if self.edge:
                    resized = self.__edge(resized)
                
                batch_data[folder,idx] = resized
                if self.affine:
                    batch_data_aug[folder,idx] = self.__affine(resized, M)   
                if self.flip:
                    batch_data_flip[folder,idx] = self.__flip(resized)   

            batch_labels[folder, int(t[folder + (batch_num*batch_size)].strip().split(';')[2])] = 1
            
            if self.affine:
                batch_labels_aug[folder, int(t[folder + (batch_num*batch_size)].strip().split(';')[2])] = 1
            
            if self.flip:
                if int(t[folder + (batch_num*batch_size)].strip().split(';')[2])==0:
                    batch_labels_flip[folder, 1] = 1
                elif int(t[folder + (batch_num*batch_size)].strip().split(';')[2])==1:
                    batch_labels_flip[folder, 0] = 1
                else:
                    batch_labels_flip[folder, int(t[folder + (batch_num*batch_size)].strip().split(';')[2])] = 1
        
        if self.affine:
            batch_data = np.append(batch_data, batch_data_aug, axis = 0) 
            batch_labels = np.append(batch_labels, batch_labels_aug, axis = 0) 
        if self.flip:
            batch_data = np.append(batch_data, batch_data_flip, axis = 0) 
            batch_labels = np.append(batch_labels, batch_labels_flip, axis = 0) 

        return batch_data, batch_labels
    
    def generator(self, source_path, folder_list, batch_size): # public method
        print( 'Source path = ', source_path, '; batch size =', batch_size)
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(folder_list)//batch_size # calculate the number of batches
            for batch in range(num_batches): # we iterate over the number of batches
                # you yield the batch_data and the batch_labels, remember what does yield do
                yield self.__load_batch_images(source_path, folder_list, batch, batch_size, t) 
            
            # Code for the remaining data points which are left after full batches
            if (len(folder_list) != batch_size*num_batches):
                batch_size = len(folder_list) - (batch_size*num_batches)
                yield self.__load_batch_images(source_path, folder_list, num_batches, batch_size, t)

    # Helper function to perfom affice transform on the image
    def __affine(self, image, M):
        return cv2.warpAffine(image, M, (image.shape[0], image.shape[1]))

    # Helper function to flip the image
    def __flip(self, image):
        return np.flip(image,1)
    
    # Helper function to normalise the data
    def __normalize(self, image):
        return image/127.5-1
    
    # Helper function to resize the image
    def __resize(self, image):
        return cv2.resize(image, (self.width,self.height), interpolation = cv2.INTER_AREA)
    
    # Helper function to crop the image
    def __crop(self, image):
        if image.shape[0] != image.shape[1]:
            return image[0:120, 20:140]
        else:
            return image

    # Helper function for edge detection
    def __edge(self, image):
        edge = np.zeros((image.shape[0], image.shape[1], image.shape[2]))
        edge[:,:,0] = cv2.Laplacian(cv2.GaussianBlur(image[:,:,0],(3,3),0),cv2.CV_64F)
        edge[:,:,1] = cv2.Laplacian(cv2.GaussianBlur(image[:,:,1],(3,3),0),cv2.CV_64F)
        edge[:,:,2] = cv2.Laplacian(cv2.GaussianBlur(image[:,:,2],(3,3),0),cv2.CV_64F)
        return edge

# %% [markdown]
# ## Model Class
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
class ModelGenerator(object):
    
    @classmethod
    def c3d1(cls, input_shape, nb_classes):
      
        # Model.
        model = Sequential()
        model.add(Conv3D(
            8, (3,3,3), activation='relu', input_shape=input_shape
        ))
        model.add(MaxPooling3D(pool_size=(1, 2, 2), strides=(1, 2, 2)))
        model.add(Conv3D(16, (3,3,3), activation='relu'))
        model.add(MaxPooling3D(pool_size=(1, 2, 2), strides=(1, 2, 2)))
        model.add(Conv3D(32, (3,3,3), activation='relu'))
        model.add(Conv3D(32, (3,3,3), activation='relu'))
        model.add(MaxPooling3D(pool_size=(1, 2, 2), strides=(1, 2, 2)))
        model.add(Conv3D(64, (2,2,2), activation='relu'))
        model.add(Conv3D(64, (2,2,2), activation='relu'))
        model.add(MaxPooling3D(pool_size=(1, 2, 2), strides=(1, 2, 2)))

        model.add(Flatten())
        model.add(Dense(512))
        model.add(Dropout(0.5))
        model.add(Dense(256))
        model.add(Dropout(0.5))
        model.add(Dense(nb_classes, activation='softmax'))

        return model
    
    @classmethod
    def c3d2(cls, input_shape, nb_classes):
           
        model = Sequential()
        
        # 1st layer group
        model.add(Conv3D(16, (3, 3, 3), activation='relu', padding='same', name='conv1', strides=(1, 1, 1), input_shape=input_shape))
        model.add(MaxPooling3D(pool_size=(1, 2, 2), strides=(1, 2, 2), padding='valid', name='pool1'))
     
        # 2nd layer group
        model.add(Conv3D(32, (3, 3, 3), activation='relu', padding='same', name='conv2'))
        model.add(MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='valid', name='pool2'))
        
        # 3rd layer group
        model.add(Conv3D(64, (3, 3, 3), activation='relu', padding='same', name='conv3a', strides=(1, 1, 1)))
        model.add(Conv3D(64, (3, 3, 3), activation='relu', padding='same', name='conv3b', strides=(1, 1, 1)))
        model.add(MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='valid', name='pool3'))
        
        # 4th layer group
        model.add(Conv3D(128, (3, 3, 3), activation='relu', padding='same', name='conv4a', strides=(1, 1, 1)))
        model.add(Conv3D(128, (3, 3, 3), activation='relu', padding='same', name='conv4b', strides=(1, 1, 1)))
        model.add(MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='valid', name='pool4'))

        # 5th layer group
        model.add(Conv3D(256, (3, 3, 3), activation='relu', padding='same', name='conv5a', strides=(1, 1, 1)))
        model.add(Conv3D(256, (3, 3, 3), activation='relu', padding='same', name='conv5b', strides=(1, 1, 1)))
        model.add(ZeroPadding3D(padding=(0, 1, 1)))
        model.add(MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='valid', name='pool5'))
        
        # Flatten and fully connected layers
        model.add(Flatten())
        model.add(Dense(512, activation='relu', name='fc6'))
        model.add(Dropout(0.5))
        model.add(Dense(512, activation='relu', name='fc7'))
        model.add(Dropout(0.5))
        model.add(Dense(nb_classes, activation='softmax', name='fc8'))

        return model
    
    @classmethod
    def c3d3(cls, input_shape, nb_classes):
        model = Sequential()
        model.add(Conv3D(16, kernel_size=(3, 3, 3), input_shape=input_shape, padding='same'))
        model.add(Activation('relu'))
        model.add(Conv3D(16, padding="same", kernel_size=(3, 3, 3)))
        model.add(Activation('relu'))
        model.add(MaxPooling3D(pool_size=(3, 3, 3), padding="same"))
        model.add(Dropout(0.25))

        model.add(Conv3D(32, padding="same", kernel_size=(3, 3, 3)))
        model.add(Activation('relu'))
        model.add(Conv3D(32, padding="same", kernel_size=(3, 3, 3)))
        model.add(Activation('relu'))
        model.add(MaxPooling3D(pool_size=(3, 3, 3), padding="same"))
        model.add(Dropout(0.25))

        model.add(Conv3D(32, padding="same", kernel_size=(3, 3, 3)))
        model.add(Activation('relu'))
        model.add(Conv3D(32, padding="same", kernel_size=(3, 3, 3)))
        model.add(Activation('relu'))
        model.add(MaxPooling3D(pool_size=(3, 3, 3), padding="same"))
        model.add(Dropout(0.25))

        model.add(Flatten())
        model.add(Dense(512, activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.5))
        model.add(Dense(nb_classes, activation='softmax'))

        return model
 
    @classmethod
    def c3d4(cls, input_shape, nb_classes):
        # Define model conv3d model
        model = Sequential()

        model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=input_shape, padding='same'))
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        model.add(MaxPooling3D(pool_size=(2,2,2)))

        model.add(Conv3D(16, kernel_size=(3,3,3), padding='same'))
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        model.add(MaxPooling3D(pool_size=(2,2,2)))

        model.add(Conv3D(32, kernel_size=(1,3,3), padding='same'))
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        model.add(MaxPooling3D(pool_size=(2,2,2)))

        model.add(Conv3D(64, kernel_size=(1,3,3), padding='same'))
        model.add(Activation('relu'))
        model.add(Dropout(0.25))

        model.add(MaxPooling3D(pool_size=(2,2,2)))

        #Flatten Layers
        model.add(Flatten())

        model.add(Dense(256, activation='relu'))
        model.add(Dropout(0.5))

        model.add(Dense(128, activation='relu'))
        model.add(Dropout(0.5))

        #softmax layer
        model.add(Dense(5, activation='softmax'))
        return model
    
    @classmethod
    def c3d5(cls, input_shape, nb_classes):
        # Define model MaxPooling3D
        model = Sequential()

        model.add(Conv3D(8, kernel_size=(3,3,3), input_shape=input_shape, padding='same'))
        #model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(Dropout(0.25))

        model.add(MaxPooling3D(pool_size=(2,2,2)))

        model.add(Conv3D(16, kernel_size=(3,3,3), padding='same'))
        #model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(Dropout(0.25))

        model.add(MaxPooling3D(pool_size=(2,2,2)))

        model.add(Conv3D(32, kernel_size=(1,3,3), padding='same'))
        #model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(Dropout(0.25))

        model.add(MaxPooling3D(pool_size=(2,2,2)))

        model.add(Conv3D(64, kernel_size=(1,3,3), padding='same'))
        model.add(Activation('relu'))
        model.add(Dropout(0.25))

        model.add(MaxPooling3D(pool_size=(2,2,2)))

        #Flatten Layers
        model.add(Flatten())

        model.add(Dense(256, activation='relu'))
        model.add(Dropout(0.5))

        model.add(Dense(128, activation='relu'))
        model.add(Dropout(0.5))

        #softmax layer
        model.add(Dense(5, activation='softmax'))
        return model   
    
    @classmethod
    def lstm(cls, input_shape, nb_classes):
        """Build a simple LSTM network. We pass the extracted features from
        our CNN to this model predomenently."""
        # Model.
        model = Sequential()
        model.add(LSTM(2048, return_sequences=False,
                       input_shape=input_shape,
                       dropout=0.5))
        model.add(Dense(512, activation='relu'))
        model.add(Dropout(0.5))
        model.add(Dense(nb_classes, activation='softmax'))

        return model

    @classmethod
    def lrcn(cls, input_shape, nb_classes):
        """Build a CNN into RNN.
        
        """
        model = Sequential()

        model.add(TimeDistributed(Conv2D(32, (7, 7), strides=(2, 2),
            activation='relu', padding='same'), input_shape=input_shape))
        model.add(TimeDistributed(Conv2D(32, (3,3),
            kernel_initializer="he_normal", activation='relu')))
        model.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))

        model.add(TimeDistributed(Conv2D(64, (3,3),
            padding='same', activation='relu')))
        model.add(TimeDistributed(Conv2D(64, (3,3),
            padding='same', activation='relu')))
        model.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))

        model.add(TimeDistributed(Conv2D(128, (3,3),
            padding='same', activation='relu')))
        model.add(TimeDistributed(Conv2D(128, (3,3),
            padding='same', activation='relu')))
        model.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))

        model.add(TimeDistributed(Conv2D(256, (3,3),
            padding='same', activation='relu')))
        model.add(TimeDistributed(Conv2D(256, (3,3),
            padding='same', activation='relu')))
        model.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))
        
        model.add(TimeDistributed(Conv2D(512, (3,3),
            padding='same', activation='relu')))
        model.add(TimeDistributed(Conv2D(512, (3,3),
            padding='same', activation='relu')))
        model.add(TimeDistributed(MaxPooling2D((2, 2), strides=(2, 2))))

        model.add(TimeDistributed(Flatten()))

        model.add(Dropout(0.5))
        model.add(LSTM(256, return_sequences=False, dropout=0.5))
        model.add(Dense(nb_classes, activation='softmax'))

        return model

    @classmethod
    def mlp(cls, input_shape, nb_classes):
        """Build a simple MLP. It uses extracted features as the input
        because of the otherwise too-high dimensionality."""
        # Model.
        model = Sequential()
        model.add(Flatten(input_shape=input_shape))
        model.add(Dense(512))
        model.add(Dropout(0.5))
        model.add(Dense(512))
        model.add(Dropout(0.5))
        model.add(Dense(nb_classes, activation='softmax'))

        return model

# %% [markdown]
# ## Trainer Function
#
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
def train(batch_size, num_epochs, model, train_generator, val_generator, optimiser=None):

    curr_dt_time = datetime.datetime.now()

    num_train_sequences = len(train_doc)
    print('# training sequences =', num_train_sequences)
    num_val_sequences = len(val_doc)
    print('# validation sequences =', num_val_sequences)
    print('# batch size =', batch_size)    
    print('# epochs =', num_epochs)

    #optimizer = Adam(lr=rate) 
    #write your optimizer
    if optimiser == None:
        optimiser = Adam() 
    model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    print (model.summary())
    
    model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
    if not os.path.exists(model_name):
        os.mkdir(model_name)
            
    filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.keras'

    checkpoint = ModelCheckpoint(
                    filepath,
                    monitor='val_loss',
                    verbose=1,
                    save_best_only=False,
                    save_weights_only=False,
                    mode='auto',
                    save_freq='epoch'  # Save the model after every epoch
                )

    LR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, cooldown=1, verbose=1)
    callbacks_list = [checkpoint, LR]

    if (num_train_sequences%batch_size) == 0:
        steps_per_epoch = int(num_train_sequences/batch_size)
    else:
        steps_per_epoch = (num_train_sequences//batch_size) + 1

    if (num_val_sequences%batch_size) == 0:
        validation_steps = int(num_val_sequences/batch_size)
    else:
        validation_steps = (num_val_sequences//batch_size) + 1

    model.fit(
            train_generator,
            steps_per_epoch=steps_per_epoch,
            epochs=num_epochs,
            verbose=1,
            callbacks=callbacks_list,
            validation_data=val_generator,
            validation_steps=validation_steps,
            class_weight=None,
            initial_epoch=0
        )
    
    K.clear_session()

# %%
from numba import cuda
def clear_cuda():
    #cuda.select_device(0)
    #cuda.close()
    pass

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv3D, MaxPooling3D, Flatten, BatchNormalization, Activation, Dropout, Input

# Define the model
model = Sequential()

# Add an explicit Input layer
model.add(Input(shape=(18, 100, 100, 3)))

# Layer 1: Conv3D and MaxPooling3D
model.add(Conv3D(16, (3, 3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# Layer 2: Conv3D and MaxPooling3D
model.add(Conv3D(32, (3, 3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# Layer 3: Conv3D and MaxPooling3D
model.add(Conv3D(64, (3, 3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# Layer 4: Conv3D and MaxPooling3D
model.add(Conv3D(128, (3, 3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=(2, 2, 2)))

# Flatten the output for the Dense layers
model.add(Flatten())

# Layer 5: Dense layer
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.25))

# Layer 6: Dense layer
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.25))

# Output layer: Softmax for classification
model.add(Dense(5, activation='softmax'))  # 5 output classes

# %% [markdown]
# ## Model #1

# %% [markdown]
# ### Model 1a : Resize to 120*120,  Raw image input, No cropping, No normalisation, No agumentation, No flipped images, No edge detection

# %%
train_gen = DataGenerator()
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d1(input_shape, num_classes)

batch_size = 20
num_epochs = 20

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # batch size = 20
# # epochs = 20
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d_24 (Conv3D)              │ (None, 28, 118, 118,   │           656 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_16 (MaxPooling3D) │ (None, 28, 59, 59, 8)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_25 (Conv3D)              │ (None, 26, 57, 57, 16) │         3,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_17 (MaxPooling3D) │ (None, 26, 28, 28, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_26 (Conv3D)              │ (None, 24, 26, 26, 32) │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_27 (Conv3D)              │ (None, 22, 24, 24, 32) │        27,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_18 (MaxPooling3D) │ (None, 22, 12, 12, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_28 (Conv3D)              │ (None, 21, 11, 11, 64) │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_29 (Conv3D)              │ (None, 20, 10, 10, 64) │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_19 (MaxPooling3D) │ (None, 20, 5, 5, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 32000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 512)            │    16,384,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,612,069 (63.37 MB)
#  Trainable params: 16,612,069 (63.37 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Source path =  ./Project_data/train ; batch size = 20
# Epoch 1/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2220 - loss: 152.6553Source path =  ./Project_data/val ; batch size = 20
#
# Epoch 1: saving model to model_init_2024-12-0315_24_36.847904/model-00001-56.67712-0.23831-1.61875-0.14000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 185s 5s/step - categorical_accuracy: 0.2225 - loss: 149.9130 - val_categorical_accuracy: 0.1400 - val_loss: 1.6187 - learning_rate: 0.0010
# Epoch 2/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 856ms/step - categorical_accuracy: 0.2096 - loss: 1.6146
# Epoch 2: saving model to model_init_2024-12-0315_24_36.847904/model-00002-1.61663-0.21569-1.66293-0.23000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - categorical_accuracy: 0.2098 - loss: 1.6146 - val_categorical_accuracy: 0.2300 - val_loss: 1.6629 - learning_rate: 0.0010
# Epoch 3/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 846ms/step - categorical_accuracy: 0.2525 - loss: 1.6310
# Epoch 3: saving model to model_init_2024-12-0315_24_36.847904/model-00003-1.63003-0.22549-1.59094-0.22000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - categorical_accuracy: 0.2517 - loss: 1.6310 - val_categorical_accuracy: 0.2200 - val_loss: 1.5909 - learning_rate: 0.0010
# Epoch 4/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 864ms/step - categorical_accuracy: 0.2511 - loss: 1.5971
# Epoch 4: saving model to model_init_2024-12-0315_24_36.847904/model-00004-1.61086-0.19608-1.60021-0.24000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - categorical_accuracy: 0.2495 - loss: 1.5975 - val_categorical_accuracy: 0.2400 - val_loss: 1.6002 - learning_rate: 0.0010
# Epoch 5/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - categorical_accuracy: 0.1395 - loss: 1.6039
# Epoch 5: saving model to model_init_2024-12-0315_24_36.847904/model-00005-1.58574-0.17647-1.57656-0.25000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 33s 978ms/step - categorical_accuracy: 0.1405 - loss: 1.6034 - val_categorical_accuracy: 0.2500 - val_loss: 1.5766 - learning_rate: 0.0010
# Epoch 6/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 847ms/step - categorical_accuracy: 0.1992 - loss: 1.6702
# Epoch 6: saving model to model_init_2024-12-0315_24_36.847904/model-00006-1.63912-0.18627-1.61528-0.18000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 34s 989ms/step - categorical_accuracy: 0.1988 - loss: 1.6694 - val_categorical_accuracy: 0.1800 - val_loss: 1.6153 - learning_rate: 0.0010
# Epoch 7/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 844ms/step - categorical_accuracy: 0.1434 - loss: 1.6272
# Epoch 7: saving model to model_init_2024-12-0315_24_36.847904/model-00007-1.61341-0.20588-1.62108-0.21000.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 34s 996ms/step - categorical_accuracy: 0.1452 - loss: 1.6268 - val_categorical_accuracy: 0.2100 - val_loss: 1.6211 - learning_rate: 0.0010
# Epoch 8/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 830ms/step - categorical_accuracy: 0.2008 - loss: 1.6065
# Epoch 8: saving model to model_init_2024-12-0315_24_36.847904/model-00008-1.60758-0.20588-1.62772-0.21000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 33s 972ms/step - categorical_accuracy: 0.2010 - loss: 1.6065 - val_categorical_accuracy: 0.2100 - val_loss: 1.6277 - learning_rate: 5.0000e-04
# Epoch 9/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 831ms/step - categorical_accuracy: 0.1529 - loss: 1.6186
# Epoch 9: saving model to model_init_2024-12-0315_24_36.847904/model-00009-1.61097-0.21569-1.62232-0.17000.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 33s 982ms/step - categorical_accuracy: 0.1547 - loss: 1.6184 - val_categorical_accuracy: 0.1700 - val_loss: 1.6223 - learning_rate: 5.0000e-04
# Epoch 10/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 842ms/step - categorical_accuracy: 0.2137 - loss: 1.6058
# Epoch 10: saving model to model_init_2024-12-0315_24_36.847904/model-00010-1.60336-0.18627-1.61848-0.19000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 34s 987ms/step - categorical_accuracy: 0.2130 - loss: 1.6058 - val_categorical_accuracy: 0.1900 - val_loss: 1.6185 - learning_rate: 2.5000e-04
# Epoch 11/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 838ms/step - categorical_accuracy: 0.2270 - loss: 1.5851
# Epoch 11: saving model to model_init_2024-12-0315_24_36.847904/model-00011-1.56868-0.23529-1.57117-0.29000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 33s 983ms/step - categorical_accuracy: 0.2272 - loss: 1.5846 - val_categorical_accuracy: 0.2900 - val_loss: 1.5712 - learning_rate: 2.5000e-04
# Epoch 12/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 849ms/step - categorical_accuracy: 0.1961 - loss: 1.6357
# Epoch 12: saving model to model_init_2024-12-0315_24_36.847904/model-00012-1.59429-0.23529-1.54707-0.33000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 34s 995ms/step - categorical_accuracy: 0.1972 - loss: 1.6345 - val_categorical_accuracy: 0.3300 - val_loss: 1.5471 - learning_rate: 2.5000e-04
# Epoch 13/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 837ms/step - categorical_accuracy: 0.4027 - loss: 1.4883
# Epoch 13: saving model to model_init_2024-12-0315_24_36.847904/model-00013-1.53495-0.36275-1.53734-0.30000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 34s 995ms/step - categorical_accuracy: 0.4016 - loss: 1.4896 - val_categorical_accuracy: 0.3000 - val_loss: 1.5373 - learning_rate: 2.5000e-04
# Epoch 14/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 879ms/step - categorical_accuracy: 0.3322 - loss: 1.5066
# Epoch 14: saving model to model_init_2024-12-0315_24_36.847904/model-00014-1.52702-0.28431-1.49973-0.34000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - categorical_accuracy: 0.3308 - loss: 1.5072 - val_categorical_accuracy: 0.3400 - val_loss: 1.4997 - learning_rate: 2.5000e-04
# Epoch 15/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 863ms/step - categorical_accuracy: 0.4015 - loss: 1.4641
# Epoch 15: saving model to model_init_2024-12-0315_24_36.847904/model-00015-1.48022-0.41176-1.51551-0.33000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - categorical_accuracy: 0.4018 - loss: 1.4646 - val_categorical_accuracy: 0.3300 - val_loss: 1.5155 - learning_rate: 2.5000e-04
# Epoch 16/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - categorical_accuracy: 0.3916 - loss: 1.4704
# Epoch 16: saving model to model_init_2024-12-0315_24_36.847904/model-00016-1.43265-0.41176-1.43610-0.36000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 33s 983ms/step - categorical_accuracy: 0.3922 - loss: 1.4693 - val_categorical_accuracy: 0.3600 - val_loss: 1.4361 - learning_rate: 2.5000e-04
# Epoch 17/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 821ms/step - categorical_accuracy: 0.4278 - loss: 1.4276
# Epoch 17: saving model to model_init_2024-12-0315_24_36.847904/model-00017-1.48814-0.38235-1.53790-0.36000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 33s 966ms/step - categorical_accuracy: 0.4265 - loss: 1.4294 - val_categorical_accuracy: 0.3600 - val_loss: 1.5379 - learning_rate: 2.5000e-04
# Epoch 18/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 878ms/step - categorical_accuracy: 0.3515 - loss: 1.5026
# Epoch 18: saving model to model_init_2024-12-0315_24_36.847904/model-00018-1.44978-0.38235-1.48053-0.35000.keras
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - categorical_accuracy: 0.3524 - loss: 1.5011 - val_categorical_accuracy: 0.3500 - val_loss: 1.4805 - learning_rate: 2.5000e-04
# Epoch 19/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 854ms/step - categorical_accuracy: 0.4004 - loss: 1.3525
# Epoch 19: saving model to model_init_2024-12-0315_24_36.847904/model-00019-1.39069-0.40196-1.49023-0.35000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - categorical_accuracy: 0.4004 - loss: 1.3536 - val_categorical_accuracy: 0.3500 - val_loss: 1.4902 - learning_rate: 1.2500e-04
# Epoch 20/20
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 854ms/step - categorical_accuracy: 0.4509 - loss: 1.3954
# Epoch 20: saving model to model_init_2024-12-0315_24_36.847904/model-00020-1.41938-0.43137-1.46490-0.39000.keras
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 34s 997ms/step - categorical_accuracy: 0.4503 - loss: 1.3961 - val_categorical_accuracy: 0.3900 - val_loss: 1.4649 - learning_rate: 1.2500e-04

# %% [markdown]
# ### Model 1b : Resize to 120*120, agumentation, No flipped images, No cropping, No normalisation, No edge detection

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Flatten, Dense

train_gen = DataGenerator(affine=True)
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d1(input_shape, num_classes)

#batch_size = 20
num_epochs = 10

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # batch size = 20
# # epochs = 10
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 28, 118, 118,   │           656 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 28, 59, 59, 8)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 26, 57, 57, 16) │         3,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 26, 28, 28, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 24, 26, 26, 32) │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 22, 24, 24, 32) │        27,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 22, 12, 12, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_4 (Conv3D)               │ (None, 21, 11, 11, 64) │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_5 (Conv3D)               │ (None, 20, 10, 10, 64) │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_3 (MaxPooling3D)  │ (None, 20, 5, 5, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    16,384,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,612,069 (63.37 MB)
#  Trainable params: 16,612,069 (63.37 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Source path =  ./Project_data/train ; batch size = 20
# Epoch 1/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - categorical_accuracy: 0.1973 - loss: 26.4666 Source path =  ./Project_data/val ; batch size = 20
#
# Epoch 1: saving model to model_init_2024-12-0315_38_27.202161/model-00001-10.67341-0.19834-1.60645-0.23000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 369s 11s/step - categorical_accuracy: 0.1973 - loss: 26.0153 - val_categorical_accuracy: 0.2300 - val_loss: 1.6064 - learning_rate: 0.0010
# Epoch 2/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2366 - loss: 1.6054
# Epoch 2: saving model to model_init_2024-12-0315_38_27.202161/model-00002-1.59244-0.28922-1.62187-0.18000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - categorical_accuracy: 0.2381 - loss: 1.6050 - val_categorical_accuracy: 0.1800 - val_loss: 1.6219 - learning_rate: 0.0010
# Epoch 3/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2225 - loss: 1.6257
# Epoch 3: saving model to model_init_2024-12-0315_38_27.202161/model-00003-1.63700-0.16667-1.61008-0.18000.keras
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - categorical_accuracy: 0.2209 - loss: 1.6260 - val_categorical_accuracy: 0.1800 - val_loss: 1.6101 - learning_rate: 0.0010
# Epoch 4/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2857 - loss: 1.5892
# Epoch 4: saving model to model_init_2024-12-0315_38_27.202161/model-00004-1.60965-0.21078-1.60420-0.17000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 83s 2s/step - categorical_accuracy: 0.2836 - loss: 1.5897 - val_categorical_accuracy: 0.1700 - val_loss: 1.6042 - learning_rate: 5.0000e-04
# Epoch 5/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2381 - loss: 1.6037
# Epoch 5: saving model to model_init_2024-12-0315_38_27.202161/model-00005-1.59713-0.19608-1.58907-0.22000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - categorical_accuracy: 0.2369 - loss: 1.6035 - val_categorical_accuracy: 0.2200 - val_loss: 1.5891 - learning_rate: 5.0000e-04
# Epoch 6/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1796 - loss: 1.6177
# Epoch 6: saving model to model_init_2024-12-0315_38_27.202161/model-00006-1.61591-0.18627-1.60567-0.23000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - categorical_accuracy: 0.1798 - loss: 1.6176 - val_categorical_accuracy: 0.2300 - val_loss: 1.6057 - learning_rate: 5.0000e-04
# Epoch 7/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1274 - loss: 1.6178
# Epoch 7: saving model to model_init_2024-12-0315_38_27.202161/model-00007-1.61609-0.16667-1.60963-0.21000.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 65s 2s/step - categorical_accuracy: 0.1285 - loss: 1.6178 - val_categorical_accuracy: 0.2100 - val_loss: 1.6096 - learning_rate: 5.0000e-04
# Epoch 8/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2545 - loss: 1.6061
# Epoch 8: saving model to model_init_2024-12-0315_38_27.202161/model-00008-1.60934-0.20588-1.60796-0.22000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - categorical_accuracy: 0.2531 - loss: 1.6061 - val_categorical_accuracy: 0.2200 - val_loss: 1.6080 - learning_rate: 2.5000e-04
# Epoch 9/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2017 - loss: 1.6107
# Epoch 9: saving model to model_init_2024-12-0315_38_27.202161/model-00009-1.61493-0.22059-1.60750-0.21000.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - categorical_accuracy: 0.2023 - loss: 1.6109 - val_categorical_accuracy: 0.2100 - val_loss: 1.6075 - learning_rate: 2.5000e-04
# Epoch 10/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2165 - loss: 1.6077
# Epoch 10: saving model to model_init_2024-12-0315_38_27.202161/model-00010-1.60637-0.23529-1.60847-0.21000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - categorical_accuracy: 0.2170 - loss: 1.6077 - val_categorical_accuracy: 0.2100 - val_loss: 1.6085 - learning_rate: 1.2500e-04

# %% [markdown]
# ### Model 1c : Resize to 120*120, agumentation, flipped images, No normalisation, No cropping, No edge detection

# %%
train_gen = DataGenerator(affine=True, flip=True)
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d1(input_shape, num_classes)

#batch_size = 20
num_epochs = 10

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # batch size = 20
# # epochs = 10
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 28, 118, 118,   │           656 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 28, 59, 59, 8)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 26, 57, 57, 16) │         3,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 26, 28, 28, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 24, 26, 26, 32) │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 22, 24, 24, 32) │        27,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 22, 12, 12, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_4 (Conv3D)               │ (None, 21, 11, 11, 64) │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_5 (Conv3D)               │ (None, 20, 10, 10, 64) │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_3 (MaxPooling3D)  │ (None, 20, 5, 5, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    16,384,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,612,069 (63.37 MB)
#  Trainable params: 16,612,069 (63.37 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Source path =  ./Project_data/train ; batch size = 20
# Epoch 1/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 15s/step - categorical_accuracy: 0.2164 - loss: 66.3786 Source path =  ./Project_data/val ; batch size = 20
#
# Epoch 1: saving model to model_init_2024-12-0315_55_00.867354/model-00001-24.44917-0.23580-1.49945-0.26000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 508s 15s/step - categorical_accuracy: 0.2170 - loss: 65.1806 - val_categorical_accuracy: 0.2600 - val_loss: 1.4995 - learning_rate: 0.0010
# Epoch 2/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.3139 - loss: 1.4591
# Epoch 2: saving model to model_init_2024-12-0315_55_00.867354/model-00002-1.41663-0.35294-1.44316-0.38000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - categorical_accuracy: 0.3150 - loss: 1.4579 - val_categorical_accuracy: 0.3800 - val_loss: 1.4432 - learning_rate: 0.0010
# Epoch 3/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.4632 - loss: 1.2832
# Epoch 3: saving model to model_init_2024-12-0315_55_00.867354/model-00003-1.28676-0.49346-1.16005-0.61000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - categorical_accuracy: 0.4640 - loss: 1.2833 - val_categorical_accuracy: 0.6100 - val_loss: 1.1600 - learning_rate: 0.0010
# Epoch 4/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5122 - loss: 1.0649
# Epoch 4: saving model to model_init_2024-12-0315_55_00.867354/model-00004-1.01421-0.56209-0.89287-0.63000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 81s 2s/step - categorical_accuracy: 0.5137 - loss: 1.0635 - val_categorical_accuracy: 0.6300 - val_loss: 0.8929 - learning_rate: 0.0010
# Epoch 5/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5429 - loss: 1.3068
# Epoch 5: saving model to model_init_2024-12-0315_55_00.867354/model-00005-1.15042-0.53595-0.92354-0.65000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - categorical_accuracy: 0.5427 - loss: 1.3023 - val_categorical_accuracy: 0.6500 - val_loss: 0.9235 - learning_rate: 0.0010
# Epoch 6/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5729 - loss: 1.0844
# Epoch 6: saving model to model_init_2024-12-0315_55_00.867354/model-00006-1.00054-0.59804-0.82872-0.69000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - categorical_accuracy: 0.5736 - loss: 1.0820 - val_categorical_accuracy: 0.6900 - val_loss: 0.8287 - learning_rate: 0.0010
# Epoch 7/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5651 - loss: 1.0958
# Epoch 7: saving model to model_init_2024-12-0315_55_00.867354/model-00007-1.06415-0.59804-1.18171-0.51000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 84s 2s/step - categorical_accuracy: 0.5660 - loss: 1.0949 - val_categorical_accuracy: 0.5100 - val_loss: 1.1817 - learning_rate: 0.0010
# Epoch 8/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5755 - loss: 1.1005
# Epoch 8: saving model to model_init_2024-12-0315_55_00.867354/model-00008-1.02636-0.59477-0.78883-0.64000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - categorical_accuracy: 0.5761 - loss: 1.0984 - val_categorical_accuracy: 0.6400 - val_loss: 0.7888 - learning_rate: 0.0010
# Epoch 9/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.7293 - loss: 0.7073
# Epoch 9: saving model to model_init_2024-12-0315_55_00.867354/model-00009-0.67128-0.73856-0.70417-0.69000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - categorical_accuracy: 0.7296 - loss: 0.7063 - val_categorical_accuracy: 0.6900 - val_loss: 0.7042 - learning_rate: 0.0010
# Epoch 10/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6628 - loss: 0.8711
# Epoch 10: saving model to model_init_2024-12-0315_55_00.867354/model-00010-0.92653-0.63725-0.83428-0.65000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - categorical_accuracy: 0.6621 - loss: 0.8727 - val_categorical_accuracy: 0.6500 - val_loss: 0.8343 - learning_rate: 0.0010

# %% [markdown]
# ### Model 1d : Resize to 120*120,  agumentation, flipped images, normalisation, No cropping, No edge detection

# %%
train_gen = DataGenerator(affine=True, flip=True, normalize=True)
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d1(input_shape, num_classes)

#batch_size = 20
num_epochs = 10

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # batch size = 20
# # epochs = 10
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 28, 118, 118,   │           656 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 28, 59, 59, 8)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 26, 57, 57, 16) │         3,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 26, 28, 28, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 24, 26, 26, 32) │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 22, 24, 24, 32) │        27,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 22, 12, 12, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_4 (Conv3D)               │ (None, 21, 11, 11, 64) │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_5 (Conv3D)               │ (None, 20, 10, 10, 64) │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_3 (MaxPooling3D)  │ (None, 20, 5, 5, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    16,384,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,612,069 (63.37 MB)
#  Trainable params: 16,612,069 (63.37 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Source path =  ./Project_data/train ; batch size = 20
# Epoch 1/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.2417 - loss: 1.6967 Source path =  ./Project_data/val ; batch size = 20
#
# Epoch 1: saving model to model_init_2024-12-0316_15_43.172628/model-00001-1.58480-0.28658-317.43524-0.23000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 432s 13s/step - categorical_accuracy: 0.2430 - loss: 1.6935 - val_categorical_accuracy: 0.2300 - val_loss: 317.4352 - learning_rate: 0.0010
# Epoch 2/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2658 - loss: 1.4741
# Epoch 2: saving model to model_init_2024-12-0316_15_43.172628/model-00002-1.58474-0.25163-115.15537-0.20000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - categorical_accuracy: 0.2654 - loss: 1.4773 - val_categorical_accuracy: 0.2000 - val_loss: 115.1554 - learning_rate: 0.0010
# Epoch 3/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1560 - loss: 1.6650
# Epoch 3: saving model to model_init_2024-12-0316_15_43.172628/model-00003-1.62737-0.19608-6.77527-0.30000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - categorical_accuracy: 0.1572 - loss: 1.6639 - val_categorical_accuracy: 0.3000 - val_loss: 6.7753 - learning_rate: 0.0010
# Epoch 4/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1897 - loss: 1.5782
# Epoch 4: saving model to model_init_2024-12-0316_15_43.172628/model-00004-1.48331-0.30065-210.78989-0.25000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - categorical_accuracy: 0.1928 - loss: 1.5755 - val_categorical_accuracy: 0.2500 - val_loss: 210.7899 - learning_rate: 0.0010
# Epoch 5/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.4524 - loss: 1.4672
# Epoch 5: saving model to model_init_2024-12-0316_15_43.172628/model-00005-1.35695-0.42810-695.12280-0.36000.keras
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - categorical_accuracy: 0.4517 - loss: 1.4640 - val_categorical_accuracy: 0.3600 - val_loss: 695.1228 - learning_rate: 0.0010
# Epoch 6/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5135 - loss: 1.3669
# Epoch 6: saving model to model_init_2024-12-0316_15_43.172628/model-00006-1.13047-0.51961-354.17117-0.40000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - categorical_accuracy: 0.5136 - loss: 1.3602 - val_categorical_accuracy: 0.4000 - val_loss: 354.1712 - learning_rate: 5.0000e-04
# Epoch 7/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5861 - loss: 1.0161
# Epoch 7: saving model to model_init_2024-12-0316_15_43.172628/model-00007-1.00276-0.57190-131.75484-0.42000.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - categorical_accuracy: 0.5857 - loss: 1.0157 - val_categorical_accuracy: 0.4200 - val_loss: 131.7548 - learning_rate: 5.0000e-04
# Epoch 8/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6055 - loss: 0.8452
# Epoch 8: saving model to model_init_2024-12-0316_15_43.172628/model-00008-0.83858-0.61438-256.63760-0.43000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - categorical_accuracy: 0.6058 - loss: 0.8450 - val_categorical_accuracy: 0.4300 - val_loss: 256.6376 - learning_rate: 2.5000e-04
# Epoch 9/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5871 - loss: 0.9806
# Epoch 9: saving model to model_init_2024-12-0316_15_43.172628/model-00009-0.94953-0.58170-337.40109-0.43000.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - categorical_accuracy: 0.5869 - loss: 0.9798 - val_categorical_accuracy: 0.4300 - val_loss: 337.4011 - learning_rate: 2.5000e-04
# Epoch 10/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6716 - loss: 0.7328
# Epoch 10: saving model to model_init_2024-12-0316_15_43.172628/model-00010-0.79382-0.65359-337.15393-0.43000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - categorical_accuracy: 0.6711 - loss: 0.7346 - val_categorical_accuracy: 0.4300 - val_loss: 337.1539 - learning_rate: 1.2500e-04

# %% [markdown]
# ### Model 1e : Resize to 120*120,  agumentation, flipped images, normalisation, cropping, No edge detection

# %%
train_gen = DataGenerator(affine=True, flip=True, normalize=True, crop=True)
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d1(input_shape, num_classes)

#batch_size = 20
num_epochs = 10

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # batch size = 20
# # epochs = 10
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 28, 118, 118,   │           656 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 28, 59, 59, 8)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 26, 57, 57, 16) │         3,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 26, 28, 28, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 24, 26, 26, 32) │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 22, 24, 24, 32) │        27,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 22, 12, 12, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_4 (Conv3D)               │ (None, 21, 11, 11, 64) │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_5 (Conv3D)               │ (None, 20, 10, 10, 64) │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_3 (MaxPooling3D)  │ (None, 20, 5, 5, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    16,384,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,612,069 (63.37 MB)
#  Trainable params: 16,612,069 (63.37 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Source path =  ./Project_data/train ; batch size = 20
# Epoch 1/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 13s/step - categorical_accuracy: 0.2062 - loss: 2.5184 Source path =  ./Project_data/val ; batch size = 20
#
# Epoch 1: saving model to model_init_2024-12-0316_33_15.039225/model-00001-1.93483-0.19457-3.47630-0.21000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 441s 13s/step - categorical_accuracy: 0.2059 - loss: 2.5017 - val_categorical_accuracy: 0.2100 - val_loss: 3.4763 - learning_rate: 0.0010
# Epoch 2/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.3562 - loss: 1.5961
# Epoch 2: saving model to model_init_2024-12-0316_33_15.039225/model-00002-1.61539-0.23529-3.42137-0.19000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - categorical_accuracy: 0.3528 - loss: 1.5967 - val_categorical_accuracy: 0.1900 - val_loss: 3.4214 - learning_rate: 0.0010
# Epoch 3/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.3112 - loss: 1.5962
# Epoch 3: saving model to model_init_2024-12-0316_33_15.039225/model-00003-1.60180-0.27778-3.42033-0.21000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - categorical_accuracy: 0.3102 - loss: 1.5964 - val_categorical_accuracy: 0.2100 - val_loss: 3.4203 - learning_rate: 0.0010
# Epoch 4/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1618 - loss: 1.6408
# Epoch 4: saving model to model_init_2024-12-0316_33_15.039225/model-00004-1.62514-0.17647-3.34215-0.20000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - categorical_accuracy: 0.1622 - loss: 1.6404 - val_categorical_accuracy: 0.2000 - val_loss: 3.3421 - learning_rate: 0.0010
# Epoch 5/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2016 - loss: 1.6064
# Epoch 5: saving model to model_init_2024-12-0316_33_15.039225/model-00005-1.61157-0.21242-3.55280-0.22000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - categorical_accuracy: 0.2019 - loss: 1.6065 - val_categorical_accuracy: 0.2200 - val_loss: 3.5528 - learning_rate: 0.0010
# Epoch 6/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2361 - loss: 1.6142
# Epoch 6: saving model to model_init_2024-12-0316_33_15.039225/model-00006-1.60079-0.25163-3.35296-0.22000.keras
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - categorical_accuracy: 0.2365 - loss: 1.6138 - val_categorical_accuracy: 0.2200 - val_loss: 3.3530 - learning_rate: 0.0010
# Epoch 7/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2101 - loss: 1.6471
# Epoch 7: saving model to model_init_2024-12-0316_33_15.039225/model-00007-1.63481-0.19608-3.27007-0.23000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - categorical_accuracy: 0.2097 - loss: 1.6467 - val_categorical_accuracy: 0.2300 - val_loss: 3.2701 - learning_rate: 5.0000e-04
# Epoch 8/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2658 - loss: 1.6118
# Epoch 8: saving model to model_init_2024-12-0316_33_15.039225/model-00008-1.61262-0.22222-3.26791-0.22000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - categorical_accuracy: 0.2646 - loss: 1.6118 - val_categorical_accuracy: 0.2200 - val_loss: 3.2679 - learning_rate: 5.0000e-04
# Epoch 9/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1012 - loss: 1.6171
# Epoch 9: saving model to model_init_2024-12-0316_33_15.039225/model-00009-1.61637-0.14379-3.24277-0.23000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - categorical_accuracy: 0.1024 - loss: 1.6171 - val_categorical_accuracy: 0.2300 - val_loss: 3.2428 - learning_rate: 5.0000e-04
# Epoch 10/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2236 - loss: 1.6132
# Epoch 10: saving model to model_init_2024-12-0316_33_15.039225/model-00010-1.62473-0.16993-3.18941-0.22000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - categorical_accuracy: 0.2221 - loss: 1.6135 - val_categorical_accuracy: 0.2200 - val_loss: 3.1894 - learning_rate: 5.0000e-04

# %% [markdown]
# ### Model 1f : Resize to 120*120,  agumentation, flipped images, normalisation, cropping, edge detection

# %%
train_gen = DataGenerator(affine=True, flip=True, normalize=True, crop=True, edge=True)
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d1(input_shape, num_classes)

#batch_size = 20
#num_epochs = 20

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # batch size = 20
# # epochs = 10
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 28, 118, 118,   │           656 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 28, 59, 59, 8)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 26, 57, 57, 16) │         3,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 26, 28, 28, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 24, 26, 26, 32) │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 22, 24, 24, 32) │        27,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 22, 12, 12, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_4 (Conv3D)               │ (None, 21, 11, 11, 64) │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_5 (Conv3D)               │ (None, 20, 10, 10, 64) │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_3 (MaxPooling3D)  │ (None, 20, 5, 5, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32000)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    16,384,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │         1,285 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,612,069 (63.37 MB)
#  Trainable params: 16,612,069 (63.37 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Source path =  ./Project_data/train ; batch size = 20
# Epoch 1/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 39s/step - categorical_accuracy: 0.2236 - loss: 2.0076 Source path =  ./Project_data/val ; batch size = 20
#
# Epoch 1: saving model to model_init_2024-12-0316_51_05.581160/model-00001-1.71804-0.24183-527.62549-0.22000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1301s 39s/step - categorical_accuracy: 0.2241 - loss: 1.9993 - val_categorical_accuracy: 0.2200 - val_loss: 527.6255 - learning_rate: 0.0010
# Epoch 2/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2220 - loss: 1.6148
# Epoch 2: saving model to model_init_2024-12-0316_51_05.581160/model-00002-1.65569-0.21242-4.53692-0.28000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - categorical_accuracy: 0.2217 - loss: 1.6160 - val_categorical_accuracy: 0.2800 - val_loss: 4.5369 - learning_rate: 0.0010
# Epoch 3/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1247 - loss: 1.6410
# Epoch 3: saving model to model_init_2024-12-0316_51_05.581160/model-00003-1.62522-0.14379-3.77223-0.25000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - categorical_accuracy: 0.1252 - loss: 1.6406 - val_categorical_accuracy: 0.2500 - val_loss: 3.7722 - learning_rate: 0.0010
# Epoch 4/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2268 - loss: 1.6165
# Epoch 4: saving model to model_init_2024-12-0316_51_05.581160/model-00004-1.62387-0.18301-3.47598-0.29000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - categorical_accuracy: 0.2255 - loss: 1.6167 - val_categorical_accuracy: 0.2900 - val_loss: 3.4760 - learning_rate: 0.0010
# Epoch 5/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2779 - loss: 1.6051
# Epoch 5: saving model to model_init_2024-12-0316_51_05.581160/model-00005-1.62579-0.21242-3.36431-0.29000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - categorical_accuracy: 0.2760 - loss: 1.6057 - val_categorical_accuracy: 0.2900 - val_loss: 3.3643 - learning_rate: 0.0010
# Epoch 6/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1837 - loss: 1.6121
# Epoch 6: saving model to model_init_2024-12-0316_51_05.581160/model-00006-1.61055-0.20261-3.35934-0.28000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - categorical_accuracy: 0.1842 - loss: 1.6120 - val_categorical_accuracy: 0.2800 - val_loss: 3.3593 - learning_rate: 0.0010
# Epoch 7/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2243 - loss: 1.6232
# Epoch 7: saving model to model_init_2024-12-0316_51_05.581160/model-00007-1.61491-0.22222-3.34047-0.25000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - categorical_accuracy: 0.2242 - loss: 1.6229 - val_categorical_accuracy: 0.2500 - val_loss: 3.3405 - learning_rate: 0.0010
# Epoch 8/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1704 - loss: 1.6331
# Epoch 8: saving model to model_init_2024-12-0316_51_05.581160/model-00008-1.62972-0.16993-3.19987-0.28000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 86s 3s/step - categorical_accuracy: 0.1704 - loss: 1.6330 - val_categorical_accuracy: 0.2800 - val_loss: 3.1999 - learning_rate: 0.0010
# Epoch 9/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1722 - loss: 1.6252
# Epoch 9: saving model to model_init_2024-12-0316_51_05.581160/model-00009-1.62147-0.16993-3.15686-0.28000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - categorical_accuracy: 0.1722 - loss: 1.6250 - val_categorical_accuracy: 0.2800 - val_loss: 3.1569 - learning_rate: 0.0010
# Epoch 10/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1679 - loss: 1.6113
# Epoch 10: saving model to model_init_2024-12-0316_51_05.581160/model-00010-1.60792-0.19935-3.04669-0.23000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - categorical_accuracy: 0.1688 - loss: 1.6112 - val_categorical_accuracy: 0.2300 - val_loss: 3.0467 - learning_rate: 0.0010

# %% [markdown]
# ## Model #2

# %% [markdown]
# ### Model 2a : Resize to 120*120,  No agumentation, No flipped images, No normalisation, No cropping, No edge detection

# %%
train_gen = DataGenerator()
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d2(input_shape, num_classes)

#batch_size = 20
#num_epochs = 20

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # batch size = 20
# # epochs = 10
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1 (Conv3D)                  │ (None, 30, 120, 120,   │         1,312 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool1 (MaxPooling3D)            │ (None, 30, 60, 60, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2 (Conv3D)                  │ (None, 30, 60, 60, 32) │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool2 (MaxPooling3D)            │ (None, 15, 30, 30, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3a (Conv3D)                 │ (None, 15, 30, 30, 64) │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3b (Conv3D)                 │ (None, 15, 30, 30, 64) │       110,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool3 (MaxPooling3D)            │ (None, 7, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv4a (Conv3D)                 │ (None, 7, 15, 15, 128) │       221,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv4b (Conv3D)                 │ (None, 7, 15, 15, 128) │       442,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool4 (MaxPooling3D)            │ (None, 3, 7, 7, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv5a (Conv3D)                 │ (None, 3, 7, 7, 256)   │       884,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv5b (Conv3D)                 │ (None, 3, 7, 7, 256)   │     1,769,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ zero_padding3d (ZeroPadding3D)  │ (None, 3, 9, 9, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool5 (MaxPooling3D)            │ (None, 1, 4, 4, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc6 (Dense)                     │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc7 (Dense)                     │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc8 (Dense)                     │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,862,597 (22.36 MB)
#  Trainable params: 5,862,597 (22.36 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Source path =  ./Project_data/train ; batch size = 20
# Epoch 1/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - categorical_accuracy: 0.2104 - loss: 3.5318 Source path =  ./Project_data/val ; batch size = 20
#
# Epoch 1: saving model to model_init_2024-12-0320_06_07.422536/model-00001-2.21507-0.19457-1.60737-0.22000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 344s 10s/step - categorical_accuracy: 0.2099 - loss: 3.4942 - val_categorical_accuracy: 0.2200 - val_loss: 1.6074 - learning_rate: 0.0010
# Epoch 2/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1341 - loss: 1.6135
# Epoch 2: saving model to model_init_2024-12-0320_06_07.422536/model-00002-1.61110-0.15686-1.61122-0.21000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - categorical_accuracy: 0.1347 - loss: 1.6134 - val_categorical_accuracy: 0.2100 - val_loss: 1.6112 - learning_rate: 0.0010
# Epoch 3/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1289 - loss: 1.6145
# Epoch 3: saving model to model_init_2024-12-0320_06_07.422536/model-00003-1.61479-0.10784-1.61156-0.16000.keras
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - categorical_accuracy: 0.1283 - loss: 1.6145 - val_categorical_accuracy: 0.1600 - val_loss: 1.6116 - learning_rate: 0.0010
# Epoch 4/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1618 - loss: 1.6083
# Epoch 4: saving model to model_init_2024-12-0320_06_07.422536/model-00004-1.61220-0.15686-1.61048-0.23000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - categorical_accuracy: 0.1617 - loss: 1.6084 - val_categorical_accuracy: 0.2300 - val_loss: 1.6105 - learning_rate: 5.0000e-04
# Epoch 5/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2610 - loss: 1.6037
# Epoch 5: saving model to model_init_2024-12-0320_06_07.422536/model-00005-1.60601-0.25490-1.60979-0.23000.keras
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - categorical_accuracy: 0.2609 - loss: 1.6037 - val_categorical_accuracy: 0.2300 - val_loss: 1.6098 - learning_rate: 5.0000e-04
# Epoch 6/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.1501 - loss: 1.6155
# Epoch 6: saving model to model_init_2024-12-0320_06_07.422536/model-00006-1.61032-0.14706-1.60995-0.23000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - categorical_accuracy: 0.1501 - loss: 1.6153 - val_categorical_accuracy: 0.2300 - val_loss: 1.6099 - learning_rate: 2.5000e-04
# Epoch 7/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2806 - loss: 1.6097
# Epoch 7: saving model to model_init_2024-12-0320_06_07.422536/model-00007-1.61563-0.21569-1.60949-0.23000.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - categorical_accuracy: 0.2787 - loss: 1.6098 - val_categorical_accuracy: 0.2300 - val_loss: 1.6095 - learning_rate: 2.5000e-04
# Epoch 8/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - categorical_accuracy: 0.0920 - loss: 1.6125
# Epoch 8: saving model to model_init_2024-12-0320_06_07.422536/model-00008-1.60824-0.17647-1.60924-0.23000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 410s 12s/step - categorical_accuracy: 0.0944 - loss: 1.6124 - val_categorical_accuracy: 0.2300 - val_loss: 1.6092 - learning_rate: 1.2500e-04
# Epoch 9/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2344 - loss: 1.6080
# Epoch 9: saving model to model_init_2024-12-0320_06_07.422536/model-00009-1.60710-0.19608-1.60937-0.23000.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - categorical_accuracy: 0.2333 - loss: 1.6079 - val_categorical_accuracy: 0.2300 - val_loss: 1.6094 - learning_rate: 1.2500e-04
# Epoch 10/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2122 - loss: 1.6051
# Epoch 10: saving model to model_init_2024-12-0320_06_07.422536/model-00010-1.60974-0.15686-1.60947-0.23000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - categorical_accuracy: 0.2106 - loss: 1.6053 - val_categorical_accuracy: 0.2300 - val_loss: 1.6095 - learning_rate: 6.2500e-05

# %% [markdown]
# ### Model 2b : Resize to 120*120, agumentation, No flipped images, No normalisation, No cropping, No edge detection

# %%
train_gen = DataGenerator(affine=True)
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d2(input_shape, num_classes)

#batch_size = 20
#num_epochs = 20

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # batch size = 20
# # epochs = 10
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1 (Conv3D)                  │ (None, 30, 120, 120,   │         1,312 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool1 (MaxPooling3D)            │ (None, 30, 60, 60, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2 (Conv3D)                  │ (None, 30, 60, 60, 32) │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool2 (MaxPooling3D)            │ (None, 15, 30, 30, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3a (Conv3D)                 │ (None, 15, 30, 30, 64) │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3b (Conv3D)                 │ (None, 15, 30, 30, 64) │       110,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool3 (MaxPooling3D)            │ (None, 7, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv4a (Conv3D)                 │ (None, 7, 15, 15, 128) │       221,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv4b (Conv3D)                 │ (None, 7, 15, 15, 128) │       442,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool4 (MaxPooling3D)            │ (None, 3, 7, 7, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv5a (Conv3D)                 │ (None, 3, 7, 7, 256)   │       884,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv5b (Conv3D)                 │ (None, 3, 7, 7, 256)   │     1,769,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ zero_padding3d (ZeroPadding3D)  │ (None, 3, 9, 9, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool5 (MaxPooling3D)            │ (None, 1, 4, 4, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc6 (Dense)                     │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc7 (Dense)                     │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc8 (Dense)                     │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,862,597 (22.36 MB)
#  Trainable params: 5,862,597 (22.36 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Source path =  ./Project_data/train ; batch size = 20
# Epoch 1/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 26s/step - categorical_accuracy: 0.2002 - loss: 3.8253 Source path =  ./Project_data/val ; batch size = 20
#
# Epoch 1: saving model to model_init_2024-12-0320_27_00.955434/model-00001-2.26903-0.19759-1.60076-0.23000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 886s 26s/step - categorical_accuracy: 0.2001 - loss: 3.7808 - val_categorical_accuracy: 0.2300 - val_loss: 1.6008 - learning_rate: 0.0010
# Epoch 2/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.3103 - loss: 1.6624
# Epoch 2: saving model to model_init_2024-12-0320_27_00.955434/model-00002-1.65433-0.29412-1.60476-0.19000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 112s 3s/step - categorical_accuracy: 0.3098 - loss: 1.6621 - val_categorical_accuracy: 0.1900 - val_loss: 1.6048 - learning_rate: 0.0010
# Epoch 3/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1833 - loss: 1.5712
# Epoch 3: saving model to model_init_2024-12-0320_27_00.955434/model-00003-1.58229-0.18627-1.50141-0.28000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 114s 3s/step - categorical_accuracy: 0.1833 - loss: 1.5716 - val_categorical_accuracy: 0.2800 - val_loss: 1.5014 - learning_rate: 0.0010
# Epoch 4/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2074 - loss: 1.6269
# Epoch 4: saving model to model_init_2024-12-0320_27_00.955434/model-00004-1.61918-0.19118-5.61360-0.22000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 116s 3s/step - categorical_accuracy: 0.2070 - loss: 1.6267 - val_categorical_accuracy: 0.2200 - val_loss: 5.6136 - learning_rate: 0.0010
# Epoch 5/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.2123 - loss: 2.1309
# Epoch 5: saving model to model_init_2024-12-0320_27_00.955434/model-00005-1.73948-0.22549-1.61074-0.21000.keras
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 136s 4s/step - categorical_accuracy: 0.2127 - loss: 2.1197 - val_categorical_accuracy: 0.2100 - val_loss: 1.6107 - learning_rate: 0.0010
# Epoch 6/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2127 - loss: 1.6158
# Epoch 6: saving model to model_init_2024-12-0320_27_00.955434/model-00006-1.61458-0.21569-1.60888-0.21000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 116s 3s/step - categorical_accuracy: 0.2128 - loss: 1.6158 - val_categorical_accuracy: 0.2100 - val_loss: 1.6089 - learning_rate: 5.0000e-04
# Epoch 7/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2850 - loss: 1.5993
# Epoch 7: saving model to model_init_2024-12-0320_27_00.955434/model-00007-1.61185-0.18627-1.60977-0.21000.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 122s 4s/step - categorical_accuracy: 0.2822 - loss: 1.5997 - val_categorical_accuracy: 0.2100 - val_loss: 1.6098 - learning_rate: 5.0000e-04
# Epoch 8/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2352 - loss: 1.6037
# Epoch 8: saving model to model_init_2024-12-0320_27_00.955434/model-00008-1.60707-0.20588-1.61050-0.21000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 122s 4s/step - categorical_accuracy: 0.2344 - loss: 1.6038 - val_categorical_accuracy: 0.2100 - val_loss: 1.6105 - learning_rate: 2.5000e-04
# Epoch 9/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.1928 - loss: 1.6080
# Epoch 9: saving model to model_init_2024-12-0320_27_00.955434/model-00009-1.60793-0.21569-1.61072-0.21000.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 128s 4s/step - categorical_accuracy: 0.1935 - loss: 1.6080 - val_categorical_accuracy: 0.2100 - val_loss: 1.6107 - learning_rate: 2.5000e-04
# Epoch 10/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.2458 - loss: 1.6111
# Epoch 10: saving model to model_init_2024-12-0320_27_00.955434/model-00010-1.60618-0.23529-1.61056-0.21000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 134s 4s/step - categorical_accuracy: 0.2455 - loss: 1.6110 - val_categorical_accuracy: 0.2100 - val_loss: 1.6106 - learning_rate: 1.2500e-04

# %% [markdown]
# ### Model 2c : Resize to 120*120, agumentation, flipped images, No normalisation, No cropping, No edge detection

# %%
train_gen = DataGenerator(affine=True, flip=True)
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d2(input_shape, num_classes)

#batch_size = 20
#num_epochs = 20

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # batch size = 20
# # epochs = 10
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1 (Conv3D)                  │ (None, 30, 120, 120,   │         1,312 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool1 (MaxPooling3D)            │ (None, 30, 60, 60, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2 (Conv3D)                  │ (None, 30, 60, 60, 32) │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool2 (MaxPooling3D)            │ (None, 15, 30, 30, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3a (Conv3D)                 │ (None, 15, 30, 30, 64) │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3b (Conv3D)                 │ (None, 15, 30, 30, 64) │       110,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool3 (MaxPooling3D)            │ (None, 7, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv4a (Conv3D)                 │ (None, 7, 15, 15, 128) │       221,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv4b (Conv3D)                 │ (None, 7, 15, 15, 128) │       442,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool4 (MaxPooling3D)            │ (None, 3, 7, 7, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv5a (Conv3D)                 │ (None, 3, 7, 7, 256)   │       884,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv5b (Conv3D)                 │ (None, 3, 7, 7, 256)   │     1,769,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ zero_padding3d (ZeroPadding3D)  │ (None, 3, 9, 9, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ pool5 (MaxPooling3D)            │ (None, 1, 4, 4, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc6 (Dense)                     │ (None, 512)            │     2,097,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc7 (Dense)                     │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc8 (Dense)                     │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,862,597 (22.36 MB)
#  Trainable params: 5,862,597 (22.36 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Source path =  ./Project_data/train ; batch size = 20
# Epoch 1/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 34s/step - categorical_accuracy: 0.2202 - loss: 5.1075 Source path =  ./Project_data/val ; batch size = 20
#
# Epoch 1: saving model to model_init_2024-12-0321_00_08.455821/model-00001-2.74377-0.20965-1.55721-0.27000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1163s 34s/step - categorical_accuracy: 0.2199 - loss: 5.0400 - val_categorical_accuracy: 0.2700 - val_loss: 1.5572 - learning_rate: 0.0010
# Epoch 2/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.1535 - loss: 1.6282
# Epoch 2: saving model to model_init_2024-12-0321_00_08.455821/model-00002-1.61932-0.19608-1.60698-0.22000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 172s 5s/step - categorical_accuracy: 0.1548 - loss: 1.6279 - val_categorical_accuracy: 0.2200 - val_loss: 1.6070 - learning_rate: 0.0010
# Epoch 3/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.1468 - loss: 1.6171
# Epoch 3: saving model to model_init_2024-12-0321_00_08.455821/model-00003-1.61267-0.17320-1.61075-0.16000.keras
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 173s 5s/step - categorical_accuracy: 0.1475 - loss: 1.6170 - val_categorical_accuracy: 0.1600 - val_loss: 1.6108 - learning_rate: 0.0010
# Epoch 4/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.1793 - loss: 1.6094
# Epoch 4: saving model to model_init_2024-12-0321_00_08.455821/model-00004-1.60894-0.18301-1.60992-0.21000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 177s 5s/step - categorical_accuracy: 0.1794 - loss: 1.6094 - val_categorical_accuracy: 0.2100 - val_loss: 1.6099 - learning_rate: 5.0000e-04
# Epoch 5/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2337 - loss: 1.6097
# Epoch 5: saving model to model_init_2024-12-0321_00_08.455821/model-00005-1.61303-0.20261-1.60928-0.21000.keras
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 179s 5s/step - categorical_accuracy: 0.2328 - loss: 1.6098 - val_categorical_accuracy: 0.2100 - val_loss: 1.6093 - learning_rate: 5.0000e-04
# Epoch 6/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2229 - loss: 1.6075
# Epoch 6: saving model to model_init_2024-12-0321_00_08.455821/model-00006-1.60851-0.21569-1.60885-0.21000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 171s 5s/step - categorical_accuracy: 0.2227 - loss: 1.6075 - val_categorical_accuracy: 0.2100 - val_loss: 1.6088 - learning_rate: 2.5000e-04
# Epoch 7/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 65s/step - categorical_accuracy: 0.1360 - loss: 1.6135
# Epoch 7: saving model to model_init_2024-12-0321_00_08.455821/model-00007-1.61231-0.13725-1.60866-0.21000.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2173s 66s/step - categorical_accuracy: 0.1361 - loss: 1.6134 - val_categorical_accuracy: 0.2100 - val_loss: 1.6087 - learning_rate: 2.5000e-04
# Epoch 8/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2665 - loss: 1.6079
# Epoch 8: saving model to model_init_2024-12-0321_00_08.455821/model-00008-1.60880-0.22549-1.60865-0.21000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 162s 5s/step - categorical_accuracy: 0.2653 - loss: 1.6079 - val_categorical_accuracy: 0.2100 - val_loss: 1.6087 - learning_rate: 1.2500e-04
# Epoch 9/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.3301 - loss: 1.6040
# Epoch 9: saving model to model_init_2024-12-0321_00_08.455821/model-00009-1.60740-0.25817-1.60869-0.21000.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 161s 5s/step - categorical_accuracy: 0.3280 - loss: 1.6041 - val_categorical_accuracy: 0.2100 - val_loss: 1.6087 - learning_rate: 1.2500e-04
# Epoch 10/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - categorical_accuracy: 0.1389 - loss: 1.6129
# Epoch 10: saving model to model_init_2024-12-0321_00_08.455821/model-00010-1.61185-0.15686-1.60865-0.21000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 159s 5s/step - categorical_accuracy: 0.1394 - loss: 1.6129 - val_categorical_accuracy: 0.2100 - val_loss: 1.6087 - learning_rate: 6.2500e-05

# %% [markdown]
# ### Model 2d : Resize to 120*120, agumentation, flipped images, normalisation, No cropping, No edge detection

# %%
train_gen = DataGenerator(affine=True, flip=True, normalize=True)
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d2(input_shape, num_classes)

#batch_size = 20
#num_epochs = 20

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)

# %% [markdown]
# ## Model #3

# %% [markdown]
# ### Model 3a : Resize to 120*120,  No agumentation, No flipped images, No normalisation, No cropping, No edge detection

# %%
train_gen = DataGenerator()
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d3(input_shape, num_classes)

#batch_size = 20
#num_epochs = 20

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # batch size = 20
# # epochs = 10
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 30, 120, 120,   │         1,312 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 30, 120, 120,   │             0 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 30, 120, 120,   │         6,928 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 30, 120, 120,   │             0 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 10, 40, 40, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 10, 40, 40, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 10, 40, 40, 32) │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 10, 40, 40, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 10, 40, 40, 32) │        27,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 10, 40, 40, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 4, 14, 14, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 4, 14, 14, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_4 (Conv3D)               │ (None, 4, 14, 14, 32)  │        27,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 4, 14, 14, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_5 (Conv3D)               │ (None, 4, 14, 14, 32)  │        27,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 4, 14, 14, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 2, 5, 5, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 2, 5, 5, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       819,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 929,461 (3.55 MB)
#  Trainable params: 928,437 (3.54 MB)
#  Non-trainable params: 1,024 (4.00 KB)
# None
# Source path =  ./Project_data/train ; batch size = 20
# Epoch 1/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - categorical_accuracy: 0.2296 - loss: 2.3232Source path =  ./Project_data/val ; batch size = 20
#
# Epoch 1: saving model to model_init_2024-12-0323_24_27.642886/model-00001-2.12063-0.27753-26.14662-0.23000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 300s 9s/step - categorical_accuracy: 0.2310 - loss: 2.3174 - val_categorical_accuracy: 0.2300 - val_loss: 26.1466 - learning_rate: 0.0010
# Epoch 2/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.3415 - loss: 1.7443
# Epoch 2: saving model to model_init_2024-12-0323_24_27.642886/model-00002-1.76502-0.34314-12.20412-0.18000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - categorical_accuracy: 0.3415 - loss: 1.7449 - val_categorical_accuracy: 0.1800 - val_loss: 12.2041 - learning_rate: 0.0010
# Epoch 3/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.2901 - loss: 2.0317
# Epoch 3: saving model to model_init_2024-12-0323_24_27.642886/model-00003-1.83687-0.34314-14.98643-0.18000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - categorical_accuracy: 0.2916 - loss: 2.0262 - val_categorical_accuracy: 0.1800 - val_loss: 14.9864 - learning_rate: 0.0010
# Epoch 4/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.2864 - loss: 2.0007
# Epoch 4: saving model to model_init_2024-12-0323_24_27.642886/model-00004-1.93393-0.30392-4.97617-0.23000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - categorical_accuracy: 0.2869 - loss: 1.9988 - val_categorical_accuracy: 0.2300 - val_loss: 4.9762 - learning_rate: 0.0010
# Epoch 5/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.2042 - loss: 1.9939
# Epoch 5: saving model to model_init_2024-12-0323_24_27.642886/model-00005-2.00425-0.27451-2.08141-0.30000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - categorical_accuracy: 0.2062 - loss: 1.9942 - val_categorical_accuracy: 0.3000 - val_loss: 2.0814 - learning_rate: 0.0010
# Epoch 6/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.3259 - loss: 1.8401
# Epoch 6: saving model to model_init_2024-12-0323_24_27.642886/model-00006-2.03784-0.27451-3.47390-0.25000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - categorical_accuracy: 0.3244 - loss: 1.8458 - val_categorical_accuracy: 0.2500 - val_loss: 3.4739 - learning_rate: 0.0010
# Epoch 7/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.2504 - loss: 2.1144
# Epoch 7: saving model to model_init_2024-12-0323_24_27.642886/model-00007-1.97804-0.26471-8.61025-0.24000.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - categorical_accuracy: 0.2508 - loss: 2.1105 - val_categorical_accuracy: 0.2400 - val_loss: 8.6102 - learning_rate: 0.0010
# Epoch 8/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.2875 - loss: 1.8912
# Epoch 8: saving model to model_init_2024-12-0323_24_27.642886/model-00008-1.91598-0.32353-7.06188-0.24000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - categorical_accuracy: 0.2885 - loss: 1.8919 - val_categorical_accuracy: 0.2400 - val_loss: 7.0619 - learning_rate: 5.0000e-04
# Epoch 9/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.3362 - loss: 1.7414
# Epoch 9: saving model to model_init_2024-12-0323_24_27.642886/model-00009-1.77224-0.29412-6.52779-0.20000.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - categorical_accuracy: 0.3350 - loss: 1.7422 - val_categorical_accuracy: 0.2000 - val_loss: 6.5278 - learning_rate: 5.0000e-04
# Epoch 10/10
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.3525 - loss: 1.7831
# Epoch 10: saving model to model_init_2024-12-0323_24_27.642886/model-00010-1.92840-0.25490-5.59241-0.19000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - categorical_accuracy: 0.3497 - loss: 1.7872 - val_categorical_accuracy: 0.1900 - val_loss: 5.5924 - learning_rate: 2.5000e-04

# %% [markdown]
# ### Model 3b : Resize to 120*120,   agumentation, No flipped images, No normalisation, No cropping, No edge detection

# %%
train_gen = DataGenerator(affine=True)
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d3(input_shape, num_classes)

#batch_size = 20
#num_epochs = 20

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # batch size = 90
# # epochs = 10
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 30, 120, 120,   │         1,312 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 30, 120, 120,   │             0 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 30, 120, 120,   │         6,928 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 30, 120, 120,   │             0 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 10, 40, 40, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 10, 40, 40, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 10, 40, 40, 32) │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 10, 40, 40, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 10, 40, 40, 32) │        27,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 10, 40, 40, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 4, 14, 14, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 4, 14, 14, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_4 (Conv3D)               │ (None, 4, 14, 14, 32)  │        27,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 4, 14, 14, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_5 (Conv3D)               │ (None, 4, 14, 14, 32)  │        27,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 4, 14, 14, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 2, 5, 5, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 2, 5, 5, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       819,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 929,461 (3.55 MB)
#  Trainable params: 928,437 (3.54 MB)
#  Non-trainable params: 1,024 (4.00 KB)
# None
# Source path =  ./Project_data/train ; batch size = 90
# Epoch 1/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 201s/step - categorical_accuracy: 0.2765 - loss: 2.2717  Source path =  ./Project_data/val ; batch size = 90
#
# Epoch 1: saving model to model_init_2024-12-0411_36_04.300834/model-00001-2.16140-0.30392-40.46215-0.23000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1678s 204s/step - categorical_accuracy: 0.2796 - loss: 2.2595 - val_categorical_accuracy: 0.2300 - val_loss: 40.4622 - learning_rate: 0.0010
# Epoch 2/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38s/step - categorical_accuracy: 0.4101 - loss: 1.7454
# Epoch 2: saving model to model_init_2024-12-0411_36_04.300834/model-00002-1.73878-0.40152-32.46897-0.20000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 309s 38s/step - categorical_accuracy: 0.4091 - loss: 1.7447 - val_categorical_accuracy: 0.2000 - val_loss: 32.4690 - learning_rate: 0.0010
# Epoch 3/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37s/step - categorical_accuracy: 0.3669 - loss: 1.7647
# Epoch 3: saving model to model_init_2024-12-0411_36_04.300834/model-00003-1.71571-0.39205-26.14246-0.35000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 300s 37s/step - categorical_accuracy: 0.3697 - loss: 1.7593 - val_categorical_accuracy: 0.3500 - val_loss: 26.1425 - learning_rate: 0.0010
# Epoch 4/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - categorical_accuracy: 0.4682 - loss: 1.4864
# Epoch 4: saving model to model_init_2024-12-0411_36_04.300834/model-00004-1.52326-0.45833-17.01696-0.40000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 156s 17s/step - categorical_accuracy: 0.4671 - loss: 1.4905 - val_categorical_accuracy: 0.4000 - val_loss: 17.0170 - learning_rate: 0.0010
# Epoch 5/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5880 - loss: 1.4868
# Epoch 5: saving model to model_init_2024-12-0411_36_04.300834/model-00005-2.20251-0.43750-14.07040-0.10000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 28s 4s/step - categorical_accuracy: 0.5713 - loss: 1.5663 - val_categorical_accuracy: 0.1000 - val_loss: 14.0704 - learning_rate: 0.0010
# Epoch 6/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.4000 - loss: 1.7396
# Epoch 6: saving model to model_init_2024-12-0411_36_04.300834/model-00006-1.56647-0.45833-15.86799-0.10000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - categorical_accuracy: 0.4064 - loss: 1.7204 - val_categorical_accuracy: 0.1000 - val_loss: 15.8680 - learning_rate: 0.0010
# Epoch 7/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.4182 - loss: 1.4682
# Epoch 7: saving model to model_init_2024-12-0411_36_04.300834/model-00007-1.52839-0.43750-9.52925-0.15000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 28s 4s/step - categorical_accuracy: 0.4203 - loss: 1.4749 - val_categorical_accuracy: 0.1500 - val_loss: 9.5293 - learning_rate: 0.0010
# Epoch 8/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.4657 - loss: 1.5967
# Epoch 8: saving model to model_init_2024-12-0411_36_04.300834/model-00008-1.93616-0.41667-8.93788-0.10000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - categorical_accuracy: 0.4602 - loss: 1.6344 - val_categorical_accuracy: 0.1000 - val_loss: 8.9379 - learning_rate: 0.0010
# Epoch 9/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.2993 - loss: 2.0238
# Epoch 9: saving model to model_init_2024-12-0411_36_04.300834/model-00009-1.77241-0.39583-8.58927-0.40000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 29s 4s/step - categorical_accuracy: 0.3101 - loss: 1.9958 - val_categorical_accuracy: 0.4000 - val_loss: 8.5893 - learning_rate: 0.0010
# Epoch 10/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.3378 - loss: 1.9838
# Epoch 10: saving model to model_init_2024-12-0411_36_04.300834/model-00010-1.96058-0.33333-9.46504-0.35000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 28s 4s/step - categorical_accuracy: 0.3373 - loss: 1.9812 - val_categorical_accuracy: 0.3500 - val_loss: 9.4650 - learning_rate: 0.0010

# %% [markdown]
# ### Model 3c : Resize to 120*120,  agumentation, flipped images, No normalisation, No cropping, No edge detection

# %%
train_gen = DataGenerator(affine=True, flip=True, normalize=True)
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d3(input_shape, num_classes)

#batch_size = 20
#num_epochs = 20

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # batch size = 90
# # epochs = 10
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 30, 120, 120,   │         1,312 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 30, 120, 120,   │             0 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 30, 120, 120,   │         6,928 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 30, 120, 120,   │             0 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 10, 40, 40, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 10, 40, 40, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 10, 40, 40, 32) │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 10, 40, 40, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 10, 40, 40, 32) │        27,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 10, 40, 40, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 4, 14, 14, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 4, 14, 14, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_4 (Conv3D)               │ (None, 4, 14, 14, 32)  │        27,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 4, 14, 14, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_5 (Conv3D)               │ (None, 4, 14, 14, 32)  │        27,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 4, 14, 14, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 2, 5, 5, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 2, 5, 5, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       819,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │         2,565 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 929,461 (3.55 MB)
#  Trainable params: 928,437 (3.54 MB)
#  Non-trainable params: 1,024 (4.00 KB)
# None
# Source path =  ./Project_data/train ; batch size = 90
# Epoch 1/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 327s/step - categorical_accuracy: 0.2654 - loss: 2.0997  Source path =  ./Project_data/val ; batch size = 90
#
# Epoch 1: saving model to model_init_2024-12-0410_18_08.736941/model-00001-1.86909-0.30769-83.69973-0.25000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2696s 329s/step - categorical_accuracy: 0.2701 - loss: 2.0741 - val_categorical_accuracy: 0.2500 - val_loss: 83.6997 - learning_rate: 0.0010
# Epoch 2/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 112s/step - categorical_accuracy: 0.3693 - loss: 1.4677
# Epoch 2: saving model to model_init_2024-12-0410_18_08.736941/model-00002-1.44017-0.38636-27.45049-0.20000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 841s 112s/step - categorical_accuracy: 0.3712 - loss: 1.4646 - val_categorical_accuracy: 0.2000 - val_loss: 27.4505 - learning_rate: 0.0010
# Epoch 3/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 74s/step - categorical_accuracy: 0.4785 - loss: 1.1126
# Epoch 3: saving model to model_init_2024-12-0410_18_08.736941/model-00003-1.12144-0.49116-29.41400-0.30000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 665s 75s/step - categorical_accuracy: 0.4799 - loss: 1.1136 - val_categorical_accuracy: 0.3000 - val_loss: 29.4140 - learning_rate: 0.0010
# Epoch 4/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25s/step - categorical_accuracy: 0.5136 - loss: 1.1941
# Epoch 4: saving model to model_init_2024-12-0410_18_08.736941/model-00004-1.18043-0.51389-11.20119-0.35000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 226s 25s/step - categorical_accuracy: 0.5136 - loss: 1.1926 - val_categorical_accuracy: 0.3500 - val_loss: 11.2012 - learning_rate: 0.0010
# Epoch 5/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.6108 - loss: 0.9773
# Epoch 5: saving model to model_init_2024-12-0410_18_08.736941/model-00005-1.23966-0.50000-13.27895-0.40000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 40s 5s/step - categorical_accuracy: 0.5985 - loss: 1.0065 - val_categorical_accuracy: 0.4000 - val_loss: 13.2790 - learning_rate: 0.0010
# Epoch 6/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.4627 - loss: 1.2918
# Epoch 6: saving model to model_init_2024-12-0410_18_08.736941/model-00006-1.06372-0.58333-28.23096-0.25000.keras
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 38s 5s/step - categorical_accuracy: 0.4761 - loss: 1.2665 - val_categorical_accuracy: 0.2500 - val_loss: 28.2310 - learning_rate: 0.0010
# Epoch 7/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.4835 - loss: 1.3112
# Epoch 7: saving model to model_init_2024-12-0410_18_08.736941/model-00007-1.22906-0.50000-23.92459-0.25000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 43s 5s/step - categorical_accuracy: 0.4853 - loss: 1.3020 - val_categorical_accuracy: 0.2500 - val_loss: 23.9246 - learning_rate: 5.0000e-04
# Epoch 8/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.5433 - loss: 0.9079
# Epoch 8: saving model to model_init_2024-12-0410_18_08.736941/model-00008-1.08684-0.50000-16.87078-0.15000.keras
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 39s 5s/step - categorical_accuracy: 0.5385 - loss: 0.9278 - val_categorical_accuracy: 0.1500 - val_loss: 16.8708 - learning_rate: 5.0000e-04
# Epoch 9/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.3850 - loss: 1.5271
# Epoch 9: saving model to model_init_2024-12-0410_18_08.736941/model-00009-1.34588-0.43056-29.87964-0.05000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 38s 5s/step - categorical_accuracy: 0.3900 - loss: 1.5070 - val_categorical_accuracy: 0.0500 - val_loss: 29.8796 - learning_rate: 2.5000e-04
# Epoch 10/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.5139 - loss: 1.1462
# Epoch 10: saving model to model_init_2024-12-0410_18_08.736941/model-00010-1.22263-0.51389-8.48382-0.30000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 39s 5s/step - categorical_accuracy: 0.5139 - loss: 1.1547 - val_categorical_accuracy: 0.3000 - val_loss: 8.4838 - learning_rate: 2.5000e-04

# %% [markdown]
# ## Model #4

# %% [markdown]
# ### Model 4a : Resize to 120*120,  No agumentation, No flipped images, No normalisation, No cropping, No edge detection

# %%
train_gen = DataGenerator()
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d4(input_shape, num_classes)

batch_size = 90
num_epochs = 10

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # batch size = 90
# # epochs = 10
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 30, 120, 120,   │           656 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 30, 120, 120,   │            32 │
# │ (BatchNormalization)            │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 30, 120, 120,   │             0 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 15, 60, 60, 8)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 15, 60, 60, 16) │         3,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 15, 60, 60, 16) │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 15, 60, 60, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 7, 30, 30, 16)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 7, 30, 30, 32)  │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 7, 30, 30, 32)  │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 7, 30, 30, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 3, 15, 15, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 3, 15, 15, 64)  │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 3, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 3, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_3 (MaxPooling3D)  │ (None, 1, 7, 7, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       803,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 864,101 (3.30 MB)
#  Trainable params: 863,989 (3.30 MB)
#  Non-trainable params: 112 (448.00 B)
# None
# Source path =  ./Project_data/train ; batch size = 90
# Epoch 1/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - categorical_accuracy: 0.1950 - loss: 2.5291 Source path =  ./Project_data/val ; batch size = 90
#
# Epoch 1: saving model to model_init_2024-12-0409_22_52.470522/model-00001-2.26780-0.20814-1.56939-0.25000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 147s 18s/step - categorical_accuracy: 0.1965 - loss: 2.5000 - val_categorical_accuracy: 0.2500 - val_loss: 1.5694 - learning_rate: 0.0010
# Epoch 2/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 434s/step - categorical_accuracy: 0.2780 - loss: 1.5504
# Epoch 2: saving model to model_init_2024-12-0409_22_52.470522/model-00002-1.54475-0.29167-1.92837-0.20000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3045s 434s/step - categorical_accuracy: 0.2795 - loss: 1.5498 - val_categorical_accuracy: 0.2000 - val_loss: 1.9284 - learning_rate: 0.0010
# Epoch 3/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - categorical_accuracy: 0.3488 - loss: 1.5160
# Epoch 3: saving model to model_init_2024-12-0409_22_52.470522/model-00003-1.51530-0.32197-2.90331-0.35000.keras
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 54s 7s/step - categorical_accuracy: 0.3458 - loss: 1.5159 - val_categorical_accuracy: 0.3500 - val_loss: 2.9033 - learning_rate: 0.0010
# Epoch 4/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.3361 - loss: 1.4125
# Epoch 4: saving model to model_init_2024-12-0409_22_52.470522/model-00004-1.39073-0.37500-3.03107-0.20000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - categorical_accuracy: 0.3405 - loss: 1.4101 - val_categorical_accuracy: 0.2000 - val_loss: 3.0311 - learning_rate: 5.0000e-04
# Epoch 5/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 642ms/step - categorical_accuracy: 0.2733 - loss: 1.3692
# Epoch 5: saving model to model_init_2024-12-0409_22_52.470522/model-00005-1.39238-0.29167-2.76728-0.20000.keras
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 746ms/step - categorical_accuracy: 0.2753 - loss: 1.3718 - val_categorical_accuracy: 0.2000 - val_loss: 2.7673 - learning_rate: 5.0000e-04
# Epoch 6/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - categorical_accuracy: 0.3096 - loss: 1.5454
# Epoch 6: saving model to model_init_2024-12-0409_22_52.470522/model-00006-1.58709-0.25000-1.98415-0.25000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 713ms/step - categorical_accuracy: 0.3030 - loss: 1.5501 - val_categorical_accuracy: 0.2500 - val_loss: 1.9842 - learning_rate: 2.5000e-04
# Epoch 7/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 615ms/step - categorical_accuracy: 0.4098 - loss: 1.3779
# Epoch 7: saving model to model_init_2024-12-0409_22_52.470522/model-00007-1.41076-0.37500-2.15637-0.15000.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 734ms/step - categorical_accuracy: 0.4059 - loss: 1.3815 - val_categorical_accuracy: 0.1500 - val_loss: 2.1564 - learning_rate: 2.5000e-04
# Epoch 8/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 608ms/step - categorical_accuracy: 0.4290 - loss: 1.3160
# Epoch 8: saving model to model_init_2024-12-0409_22_52.470522/model-00008-1.33391-0.41667-1.97817-0.25000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 710ms/step - categorical_accuracy: 0.4276 - loss: 1.3180 - val_categorical_accuracy: 0.2500 - val_loss: 1.9782 - learning_rate: 1.2500e-04
# Epoch 9/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 610ms/step - categorical_accuracy: 0.3806 - loss: 1.2127
# Epoch 9: saving model to model_init_2024-12-0409_22_52.470522/model-00009-1.35347-0.37500-1.92700-0.30000.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 712ms/step - categorical_accuracy: 0.3800 - loss: 1.2284 - val_categorical_accuracy: 0.3000 - val_loss: 1.9270 - learning_rate: 1.2500e-04
# Epoch 10/10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 609ms/step - categorical_accuracy: 0.3142 - loss: 1.4064
# Epoch 10: saving model to model_init_2024-12-0409_22_52.470522/model-00010-1.49718-0.29167-1.68669-0.25000.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 6s 706ms/step - categorical_accuracy: 0.3117 - loss: 1.4165 - val_categorical_accuracy: 0.2500 - val_loss: 1.6867 - learning_rate: 6.2500e-05

# %% [markdown]
# ### Model 4b : Resize to 120*120,  agumentation, No flipped images, No normalisation, No cropping, No edge detection

# %%
train_gen = DataGenerator(affine=True)
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d4(input_shape, num_classes)

batch_size = 50
num_epochs = 10

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # batch size = 50
# # epochs = 10
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 30, 120, 120,   │           656 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 30, 120, 120,   │            32 │
# │ (BatchNormalization)            │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 30, 120, 120,   │             0 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 15, 60, 60, 8)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 15, 60, 60, 16) │         3,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 15, 60, 60, 16) │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 15, 60, 60, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 7, 30, 30, 16)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 7, 30, 30, 32)  │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 7, 30, 30, 32)  │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 7, 30, 30, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 3, 15, 15, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 3, 15, 15, 64)  │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 3, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 3, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_3 (MaxPooling3D)  │ (None, 1, 7, 7, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       803,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 864,101 (3.30 MB)
#  Trainable params: 863,989 (3.30 MB)
#  Non-trainable params: 112 (448.00 B)
# None
# Source path =  ./Project_data/train ; batch size = 50
# Epoch 1/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20s/step - categorical_accuracy: 0.1984 - loss: 2.4609 Source path =  ./Project_data/val ; batch size = 50
#
# Epoch 1: saving model to model_init_2024-12-0323_37_44.861324/model-00001-1.99988-0.22323-1.67662-0.18000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 291s 21s/step - categorical_accuracy: 0.2000 - loss: 2.4302 - val_categorical_accuracy: 0.1800 - val_loss: 1.6766 - learning_rate: 0.0010
# Epoch 2/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2922 - loss: 1.5227
# Epoch 2: saving model to model_init_2024-12-0323_37_44.861324/model-00002-1.52424-0.29396-1.81105-0.18000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 77s 6s/step - categorical_accuracy: 0.2923 - loss: 1.5228 - val_categorical_accuracy: 0.1800 - val_loss: 1.8110 - learning_rate: 0.0010
# Epoch 3/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.3483 - loss: 1.4541
# Epoch 3: saving model to model_init_2024-12-0323_37_44.861324/model-00003-1.43446-0.37088-2.01682-0.27000.keras
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 76s 5s/step - categorical_accuracy: 0.3498 - loss: 1.4527 - val_categorical_accuracy: 0.2700 - val_loss: 2.0168 - learning_rate: 0.0010
# Epoch 4/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.4192 - loss: 1.3760
# Epoch 4: saving model to model_init_2024-12-0323_37_44.861324/model-00004-1.36199-0.41484-2.45803-0.30000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 77s 6s/step - categorical_accuracy: 0.4189 - loss: 1.3750 - val_categorical_accuracy: 0.3000 - val_loss: 2.4580 - learning_rate: 5.0000e-04
# Epoch 5/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.4477 - loss: 1.3043
# Epoch 5: saving model to model_init_2024-12-0323_37_44.861324/model-00005-1.31202-0.45055-1.99208-0.22000.keras
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 75s 5s/step - categorical_accuracy: 0.4478 - loss: 1.3048 - val_categorical_accuracy: 0.2200 - val_loss: 1.9921 - learning_rate: 5.0000e-04
# Epoch 6/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31s/step - categorical_accuracy: 0.4373 - loss: 1.3342
# Epoch 6: saving model to model_init_2024-12-0323_37_44.861324/model-00006-1.29991-0.44505-1.96959-0.33000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 418s 32s/step - categorical_accuracy: 0.4378 - loss: 1.3319 - val_categorical_accuracy: 0.3300 - val_loss: 1.9696 - learning_rate: 2.5000e-04
# Epoch 7/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.5018 - loss: 1.3420
# Epoch 7: saving model to model_init_2024-12-0323_37_44.861324/model-00007-1.23094-0.53297-1.53556-0.33000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 73s 5s/step - categorical_accuracy: 0.5038 - loss: 1.3346 - val_categorical_accuracy: 0.3300 - val_loss: 1.5356 - learning_rate: 2.5000e-04
# Epoch 8/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.5967 - loss: 1.0161
# Epoch 8: saving model to model_init_2024-12-0323_37_44.861324/model-00008-1.10086-0.55220-1.43162-0.38000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 77s 6s/step - categorical_accuracy: 0.5937 - loss: 1.0218 - val_categorical_accuracy: 0.3800 - val_loss: 1.4316 - learning_rate: 2.5000e-04
# Epoch 9/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.5570 - loss: 1.1434
# Epoch 9: saving model to model_init_2024-12-0323_37_44.861324/model-00009-1.13424-0.53846-1.25703-0.45000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 76s 5s/step - categorical_accuracy: 0.5558 - loss: 1.1428 - val_categorical_accuracy: 0.4500 - val_loss: 1.2570 - learning_rate: 2.5000e-04
# Epoch 10/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.6076 - loss: 1.0185
# Epoch 10: saving model to model_init_2024-12-0323_37_44.861324/model-00010-0.99760-0.60165-1.23734-0.44000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 76s 5s/step - categorical_accuracy: 0.6072 - loss: 1.0171 - val_categorical_accuracy: 0.4400 - val_loss: 1.2373 - learning_rate: 2.5000e-04

# %% [markdown]
# ### Model 4c : Resize to 120*120,  agumentation,  flipped images, No normalisation, No cropping, No edge detection

# %%
train_gen = DataGenerator(affine=True, flip=True, normalize=True, crop=True)
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d4(input_shape, num_classes)

#batch_size = 20
#num_epochs = 20

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # batch size = 50
# # epochs = 10
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 30, 120, 120,   │           656 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 30, 120, 120,   │            32 │
# │ (BatchNormalization)            │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 30, 120, 120,   │             0 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 15, 60, 60, 8)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 15, 60, 60, 16) │         3,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 15, 60, 60, 16) │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 15, 60, 60, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 7, 30, 30, 16)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 7, 30, 30, 32)  │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 7, 30, 30, 32)  │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 7, 30, 30, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 3, 15, 15, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 3, 15, 15, 64)  │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 3, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 3, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_3 (MaxPooling3D)  │ (None, 1, 7, 7, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       803,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 864,101 (3.30 MB)
#  Trainable params: 863,989 (3.30 MB)
#  Non-trainable params: 112 (448.00 B)
# None
# Source path =  ./Project_data/train ; batch size = 50
# Epoch 1/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32s/step - categorical_accuracy: 0.2514 - loss: 2.2275 Source path =  ./Project_data/val ; batch size = 50
#
# Epoch 1: saving model to model_init_2024-12-0323_59_45.930738/model-00001-1.87387-0.28959-16.37091-0.29000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 455s 32s/step - categorical_accuracy: 0.2539 - loss: 2.2039 - val_categorical_accuracy: 0.2900 - val_loss: 16.3709 - learning_rate: 0.0010
# Epoch 2/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.3787 - loss: 1.4874
# Epoch 2: saving model to model_init_2024-12-0323_59_45.930738/model-00002-1.44446-0.37546-67.91635-0.34000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 110s 8s/step - categorical_accuracy: 0.3785 - loss: 1.4845 - val_categorical_accuracy: 0.3400 - val_loss: 67.9164 - learning_rate: 0.0010
# Epoch 3/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.4004 - loss: 1.4255
# Epoch 3: saving model to model_init_2024-12-0323_59_45.930738/model-00003-1.39313-0.39927-86.42780-0.26000.keras
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 111s 8s/step - categorical_accuracy: 0.4003 - loss: 1.4233 - val_categorical_accuracy: 0.2600 - val_loss: 86.4278 - learning_rate: 0.0010
# Epoch 4/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.4728 - loss: 1.2231
# Epoch 4: saving model to model_init_2024-12-0323_59_45.930738/model-00004-1.29853-0.45971-67.08882-0.35000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 112s 8s/step - categorical_accuracy: 0.4719 - loss: 1.2281 - val_categorical_accuracy: 0.3500 - val_loss: 67.0888 - learning_rate: 5.0000e-04
# Epoch 5/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.4700 - loss: 1.2663
# Epoch 5: saving model to model_init_2024-12-0323_59_45.930738/model-00005-1.25921-0.48718-64.99039-0.33000.keras
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 113s 8s/step - categorical_accuracy: 0.4712 - loss: 1.2659 - val_categorical_accuracy: 0.3300 - val_loss: 64.9904 - learning_rate: 5.0000e-04
# Epoch 6/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.4622 - loss: 1.2886
# Epoch 6: saving model to model_init_2024-12-0323_59_45.930738/model-00006-1.19776-0.50916-69.19343-0.33000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 110s 8s/step - categorical_accuracy: 0.4653 - loss: 1.2826 - val_categorical_accuracy: 0.3300 - val_loss: 69.1934 - learning_rate: 2.5000e-04
# Epoch 7/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.5092 - loss: 1.1390
# Epoch 7: saving model to model_init_2024-12-0323_59_45.930738/model-00007-1.17603-0.49634-78.39067-0.32000.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 111s 8s/step - categorical_accuracy: 0.5083 - loss: 1.1414 - val_categorical_accuracy: 0.3200 - val_loss: 78.3907 - learning_rate: 2.5000e-04
# Epoch 8/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.5043 - loss: 1.1335
# Epoch 8: saving model to model_init_2024-12-0323_59_45.930738/model-00008-1.13663-0.51282-95.16381-0.32000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 110s 8s/step - categorical_accuracy: 0.5049 - loss: 1.1337 - val_categorical_accuracy: 0.3200 - val_loss: 95.1638 - learning_rate: 1.2500e-04
# Epoch 9/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.5183 - loss: 1.1596
# Epoch 9: saving model to model_init_2024-12-0323_59_45.930738/model-00009-1.17462-0.50549-101.66910-0.33000.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 114s 8s/step - categorical_accuracy: 0.5174 - loss: 1.1606 - val_categorical_accuracy: 0.3300 - val_loss: 101.6691 - learning_rate: 1.2500e-04
# Epoch 10/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.5428 - loss: 1.1074
# Epoch 10: saving model to model_init_2024-12-0323_59_45.930738/model-00010-1.06081-0.57326-112.65527-0.31000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 111s 8s/step - categorical_accuracy: 0.5448 - loss: 1.1043 - val_categorical_accuracy: 0.3100 - val_loss: 112.6553 - learning_rate: 6.2500e-05

# %% [markdown]
# ## Model #5

# %% [markdown]
# ### Model 5a : Resize to 120*120,  No agumentation, No flipped images, No normalisation, No cropping, No edge detection

# %%
train_gen = DataGenerator()
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d5(input_shape, num_classes)

batch_size = 20
#num_epochs = 20

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # batch size = 50
# # epochs = 10
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 30, 120, 120,   │           656 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 30, 120, 120,   │             0 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 120, 120,   │             0 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 15, 60, 60, 8)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 15, 60, 60, 16) │         3,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 15, 60, 60, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 15, 60, 60, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 7, 30, 30, 16)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 7, 30, 30, 32)  │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 7, 30, 30, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 7, 30, 30, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 3, 15, 15, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 3, 15, 15, 64)  │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 3, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 3, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_3 (MaxPooling3D)  │ (None, 1, 7, 7, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       803,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 863,877 (3.30 MB)
#  Trainable params: 863,877 (3.30 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Source path =  ./Project_data/train ; batch size = 50
# Epoch 1/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - categorical_accuracy: 0.1967 - loss: 34.0064 Source path =  ./Project_data/val ; batch size = 50
#
# Epoch 1: saving model to model_init_2024-12-0400_24_11.647163/model-00001-18.55767-0.18552-1.58346-0.21000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 158s 11s/step - categorical_accuracy: 0.1960 - loss: 32.9765 - val_categorical_accuracy: 0.2100 - val_loss: 1.5835 - learning_rate: 0.0010
# Epoch 2/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2235 - loss: 2.0211
# Epoch 2: saving model to model_init_2024-12-0400_24_11.647163/model-00002-1.83362-0.21429-1.60110-0.17000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - categorical_accuracy: 0.2228 - loss: 2.0086 - val_categorical_accuracy: 0.1700 - val_loss: 1.6011 - learning_rate: 0.0010
# Epoch 3/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.2404 - loss: 1.5888
# Epoch 3: saving model to model_init_2024-12-0400_24_11.647163/model-00003-1.63240-0.18132-1.58935-0.32000.keras
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 112s 8s/step - categorical_accuracy: 0.2365 - loss: 1.5917 - val_categorical_accuracy: 0.3200 - val_loss: 1.5894 - learning_rate: 0.0010
# Epoch 4/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29s/step - categorical_accuracy: 0.1396 - loss: 1.6349
# Epoch 4: saving model to model_init_2024-12-0400_24_11.647163/model-00004-1.61969-0.16484-1.59363-0.27000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 388s 30s/step - categorical_accuracy: 0.1413 - loss: 1.6339 - val_categorical_accuracy: 0.2700 - val_loss: 1.5936 - learning_rate: 5.0000e-04
# Epoch 5/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2306 - loss: 1.5861
# Epoch 5: saving model to model_init_2024-12-0400_24_11.647163/model-00005-1.59647-0.20879-1.59023-0.29000.keras
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - categorical_accuracy: 0.2292 - loss: 1.5868 - val_categorical_accuracy: 0.2900 - val_loss: 1.5902 - learning_rate: 5.0000e-04
# Epoch 6/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2059 - loss: 1.5857
# Epoch 6: saving model to model_init_2024-12-0400_24_11.647163/model-00006-1.58340-0.20879-1.58660-0.31000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - categorical_accuracy: 0.2061 - loss: 1.5856 - val_categorical_accuracy: 0.3100 - val_loss: 1.5866 - learning_rate: 2.5000e-04
# Epoch 7/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2012 - loss: 1.5934
# Epoch 7: saving model to model_init_2024-12-0400_24_11.647163/model-00007-1.59033-0.21978-1.58398-0.31000.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - categorical_accuracy: 0.2024 - loss: 1.5932 - val_categorical_accuracy: 0.3100 - val_loss: 1.5840 - learning_rate: 2.5000e-04
# Epoch 8/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2625 - loss: 1.5300
# Epoch 8: saving model to model_init_2024-12-0400_24_11.647163/model-00008-1.56057-0.24176-1.58082-0.30000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - categorical_accuracy: 0.2612 - loss: 1.5320 - val_categorical_accuracy: 0.3000 - val_loss: 1.5808 - learning_rate: 1.2500e-04
# Epoch 9/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2259 - loss: 1.5856
# Epoch 9: saving model to model_init_2024-12-0400_24_11.647163/model-00009-1.58446-0.23077-1.57863-0.32000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 37s 3s/step - categorical_accuracy: 0.2262 - loss: 1.5856 - val_categorical_accuracy: 0.3200 - val_loss: 1.5786 - learning_rate: 1.2500e-04
# Epoch 10/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.2954 - loss: 1.5121
# Epoch 10: saving model to model_init_2024-12-0400_24_11.647163/model-00010-1.53880-0.28022-1.57563-0.32000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - categorical_accuracy: 0.2944 - loss: 1.5139 - val_categorical_accuracy: 0.3200 - val_loss: 1.5756 - learning_rate: 1.2500e-04

# %% [markdown]
# ### Model 5b : Resize to 120*120,  agumentation, No flipped images, No normalisation, No cropping, No edge detection

# %%
train_gen = DataGenerator(affine=True)
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d5(input_shape, num_classes)

#batch_size = 20
#num_epochs = 20

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # batch size = 50
# # epochs = 10
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 30, 120, 120,   │           656 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 30, 120, 120,   │             0 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 120, 120,   │             0 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 15, 60, 60, 8)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 15, 60, 60, 16) │         3,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 15, 60, 60, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 15, 60, 60, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 7, 30, 30, 16)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 7, 30, 30, 32)  │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 7, 30, 30, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 7, 30, 30, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 3, 15, 15, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 3, 15, 15, 64)  │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 3, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 3, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_3 (MaxPooling3D)  │ (None, 1, 7, 7, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       803,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 863,877 (3.30 MB)
#  Trainable params: 863,877 (3.30 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Source path =  ./Project_data/train ; batch size = 50
# Epoch 1/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32s/step - categorical_accuracy: 0.1767 - loss: 128.3439 Source path =  ./Project_data/val ; batch size = 50
#
# Epoch 1: saving model to model_init_2024-12-0400_39_40.128015/model-00001-66.63148-0.19457-1.60596-0.28000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 449s 33s/step - categorical_accuracy: 0.1779 - loss: 124.2297 - val_categorical_accuracy: 0.2800 - val_loss: 1.6060 - learning_rate: 0.0010
# Epoch 2/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2583 - loss: 2.5003
# Epoch 2: saving model to model_init_2024-12-0400_39_40.128015/model-00002-2.22200-0.26923-1.60335-0.26000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 72s 5s/step - categorical_accuracy: 0.2591 - loss: 2.4817 - val_categorical_accuracy: 0.2600 - val_loss: 1.6034 - learning_rate: 0.0010
# Epoch 3/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2112 - loss: 1.6359
# Epoch 3: saving model to model_init_2024-12-0400_39_40.128015/model-00003-1.61924-0.22253-1.59538-0.28000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 71s 5s/step - categorical_accuracy: 0.2119 - loss: 1.6347 - val_categorical_accuracy: 0.2800 - val_loss: 1.5954 - learning_rate: 0.0010
# Epoch 4/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2008 - loss: 1.6556
# Epoch 4: saving model to model_init_2024-12-0400_39_40.128015/model-00004-1.64504-0.21978-1.60234-0.31000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 71s 5s/step - categorical_accuracy: 0.2021 - loss: 1.6549 - val_categorical_accuracy: 0.3100 - val_loss: 1.6023 - learning_rate: 0.0010
# Epoch 5/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2493 - loss: 1.5885
# Epoch 5: saving model to model_init_2024-12-0400_39_40.128015/model-00005-1.60103-0.22802-1.60343-0.30000.keras
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 71s 5s/step - categorical_accuracy: 0.2479 - loss: 1.5893 - val_categorical_accuracy: 0.3000 - val_loss: 1.6034 - learning_rate: 0.0010
# Epoch 6/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.1583 - loss: 1.6401
# Epoch 6: saving model to model_init_2024-12-0400_39_40.128015/model-00006-1.62257-0.19231-1.59901-0.30000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 70s 5s/step - categorical_accuracy: 0.1606 - loss: 1.6389 - val_categorical_accuracy: 0.3000 - val_loss: 1.5990 - learning_rate: 5.0000e-04
# Epoch 7/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2575 - loss: 1.5812
# Epoch 7: saving model to model_init_2024-12-0400_39_40.128015/model-00007-1.60760-0.21978-1.59638-0.28000.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 70s 5s/step - categorical_accuracy: 0.2549 - loss: 1.5830 - val_categorical_accuracy: 0.2800 - val_loss: 1.5964 - learning_rate: 5.0000e-04
# Epoch 8/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2782 - loss: 1.5829
# Epoch 8: saving model to model_init_2024-12-0400_39_40.128015/model-00008-1.58406-0.26923-1.59659-0.31000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 70s 5s/step - categorical_accuracy: 0.2776 - loss: 1.5830 - val_categorical_accuracy: 0.3100 - val_loss: 1.5966 - learning_rate: 2.5000e-04
# Epoch 9/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2781 - loss: 1.5951
# Epoch 9: saving model to model_init_2024-12-0400_39_40.128015/model-00009-1.58136-0.27473-1.59512-0.28000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 70s 5s/step - categorical_accuracy: 0.2779 - loss: 1.5941 - val_categorical_accuracy: 0.2800 - val_loss: 1.5951 - learning_rate: 2.5000e-04
# Epoch 10/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2778 - loss: 1.5726
# Epoch 10: saving model to model_init_2024-12-0400_39_40.128015/model-00010-1.57145-0.28022-1.59421-0.28000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 73s 5s/step - categorical_accuracy: 0.2780 - loss: 1.5725 - val_categorical_accuracy: 0.2800 - val_loss: 1.5942 - learning_rate: 2.5000e-04

# %% [markdown]
# ### Model 5c : Resize to 120*120,  agumentation, flipped images, No normalisation, No cropping, No edge detection

# %%
train_gen = DataGenerator(affine=True, flip=True)
val_gen = DataGenerator()
model_gen = ModelGenerator()

input_shape = (30,120,120, 3)
num_classes = 5

model = model_gen.c3d5(input_shape, num_classes)

#batch_size = 20
#num_epochs = 20

train_generator = train_gen.generator(train_path, train_doc, batch_size)
val_generator = val_gen.generator(val_path, val_doc, batch_size)
train(batch_size, num_epochs, model, train_generator, val_generator)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # batch size = 50
# # epochs = 10
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 30, 120, 120,   │           656 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 30, 120, 120,   │             0 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 120, 120,   │             0 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 15, 60, 60, 8)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 15, 60, 60, 16) │         3,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 15, 60, 60, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 15, 60, 60, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 7, 30, 30, 16)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 7, 30, 30, 32)  │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 7, 30, 30, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 7, 30, 30, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 3, 15, 15, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 3, 15, 15, 64)  │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 3, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 3, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_3 (MaxPooling3D)  │ (None, 1, 7, 7, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       803,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 863,877 (3.30 MB)
#  Trainable params: 863,877 (3.30 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Source path =  ./Project_data/train ; batch size = 50
# Epoch 1/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30s/step - categorical_accuracy: 0.1931 - loss: 75.0665 Source path =  ./Project_data/val ; batch size = 50
#
# Epoch 1: saving model to model_init_2024-12-0400_57_51.873422/model-00001-38.77069-0.20161-1.58250-0.32000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 427s 30s/step - categorical_accuracy: 0.1936 - loss: 72.6468 - val_categorical_accuracy: 0.3200 - val_loss: 1.5825 - learning_rate: 0.0010
# Epoch 2/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.2182 - loss: 1.9387
# Epoch 2: saving model to model_init_2024-12-0400_57_51.873422/model-00002-1.79718-0.21245-1.60936-0.23000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 113s 8s/step - categorical_accuracy: 0.2178 - loss: 1.9292 - val_categorical_accuracy: 0.2300 - val_loss: 1.6094 - learning_rate: 0.0010
# Epoch 3/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.2105 - loss: 1.6598
# Epoch 3: saving model to model_init_2024-12-0400_57_51.873422/model-00003-1.63426-0.19963-1.60663-0.19000.keras
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 123s 9s/step - categorical_accuracy: 0.2098 - loss: 1.6581 - val_categorical_accuracy: 0.1900 - val_loss: 1.6066 - learning_rate: 0.0010
# Epoch 4/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1072s/step - categorical_accuracy: 0.2423 - loss: 1.6248
# Epoch 4: saving model to model_init_2024-12-0400_57_51.873422/model-00004-1.63353-0.22527-1.60599-0.26000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 13951s 1072s/step - categorical_accuracy: 0.2411 - loss: 1.6253 - val_categorical_accuracy: 0.2600 - val_loss: 1.6060 - learning_rate: 5.0000e-04
# Epoch 5/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 723s/step - categorical_accuracy: 0.2422 - loss: 1.6141
# Epoch 5: saving model to model_init_2024-12-0400_57_51.873422/model-00005-1.60938-0.23443-1.60310-0.21000.keras
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 10015s 724s/step - categorical_accuracy: 0.2417 - loss: 1.6138 - val_categorical_accuracy: 0.2100 - val_loss: 1.6031 - learning_rate: 5.0000e-04
# Epoch 6/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - categorical_accuracy: 0.2330 - loss: 1.6148
# Epoch 6: saving model to model_init_2024-12-0400_57_51.873422/model-00006-1.61866-0.21612-1.60344-0.23000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 103s 7s/step - categorical_accuracy: 0.2318 - loss: 1.6151 - val_categorical_accuracy: 0.2300 - val_loss: 1.6034 - learning_rate: 2.5000e-04
# Epoch 7/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 115s/step - categorical_accuracy: 0.2066 - loss: 1.6155
# Epoch 7: saving model to model_init_2024-12-0400_57_51.873422/model-00007-1.61106-0.21612-1.60331-0.19000.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1511s 116s/step - categorical_accuracy: 0.2073 - loss: 1.6152 - val_categorical_accuracy: 0.1900 - val_loss: 1.6033 - learning_rate: 2.5000e-04
# Epoch 8/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - categorical_accuracy: 0.2013 - loss: 1.6229
# Epoch 8: saving model to model_init_2024-12-0400_57_51.873422/model-00008-1.62374-0.19414-1.60248-0.21000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 105s 8s/step - categorical_accuracy: 0.2009 - loss: 1.6229 - val_categorical_accuracy: 0.2100 - val_loss: 1.6025 - learning_rate: 1.2500e-04
# Epoch 9/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - categorical_accuracy: 0.2178 - loss: 1.6159
# Epoch 9: saving model to model_init_2024-12-0400_57_51.873422/model-00009-1.59548-0.23993-1.60145-0.22000.keras
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 102s 7s/step - categorical_accuracy: 0.2193 - loss: 1.6145 - val_categorical_accuracy: 0.2200 - val_loss: 1.6014 - learning_rate: 1.2500e-04
# Epoch 10/10
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - categorical_accuracy: 0.2472 - loss: 1.5964
# Epoch 10: saving model to model_init_2024-12-0400_57_51.873422/model-00010-1.59463-0.23810-1.60076-0.25000.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 236s 18s/step - categorical_accuracy: 0.2466 - loss: 1.5963 - val_categorical_accuracy: 0.2500 - val_loss: 1.6008 - learning_rate: 6.2500e-05

# %%
from tensorflow.keras.models import load_model

# Load the model
model = load_model("model_init_2024-12-0411_36_04.300834/model-00010-1.96058-0.33333-9.46504-0.35000.keras")

# Save the model in HDF5 format
model.save("final.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import h5py

# Open the HDF5 file
with h5py.File("final.h5", "r") as f:
    # List all groups in the HDF5 file
    print("Keys in the HDF5 file:")
    for key in f.keys():
        print(key)

    # Explore a specific group
    print("\nModel weights structure:")
    weights_group = f["model_weights"]
    for layer in weights_group.keys():
        print(layer)

    # Explore attributes
    print("\nAttributes of the root group:")
    for attr in f.attrs:
        print(f"{attr}: {f.attrs[attr]}")
# Out:
# Keys in the HDF5 file:
# model_weights
# optimizer_weights
#
# Model weights structure:
# activation
# activation_1
# activation_2
# activation_3
# activation_4
# activation_5
# batch_normalization
# conv3d
# conv3d_1
# conv3d_2
# conv3d_3
# conv3d_4
# conv3d_5
# dense
# dense_1
# dropout
# dropout_1
# dropout_2
# dropout_3
# flatten
# max_pooling3d
# max_pooling3d_1
# max_pooling3d_2
# top_level_model_weights
#
# Attributes of the root group:
# backend: tensorflow
# keras_version: 3.6.0
# model_config: {"class_name": "Sequential", "config": {"name": "sequential", "trainable": true, "dtype": {"module": "keras", "class_name": "DTypePolicy", "config": {"name": "float32"}, "registered_name": null}, "layers": [{"class_name": "InputLayer", "config": {"batch_shape": [null, 30, 120, 120, 3], "dtype": "float32", "sparse": false, "name": "input_layer"}}, {"class_name": "Conv3D", "config": {"name": "conv3d", "trainable": true, "dtype": {"module": "keras", "class_name": "DTypePolicy", "config": {"name": "float32"}, "registered_name": null}, "filters": 16, "kernel_size": [3, 3, 3], "strides": [1, 1, 1], "padding": "same", "data_format": "channels_last", "dilation_rate": [1, 1, 1], "groups": 1, "activation": "linear", "use_bias": true, "kernel_initializer": {"module": "keras.initializers", "class_name": "GlorotUniform", "config": {"seed": null}, "registered_name": null}, "bias_initializer": {"module": "keras.initializers", "class_name": "Zeros", "config": {}, "registered_name": null}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}, {"class_name": "Activation", "config": {"name": "activation", "trainable": true, "dtype": {"module": "keras", "class_name": "DTypePolicy", "config": {"name": "float32"}, "registered_name": null}, "activation": "relu"}}, {"class_name": "Conv3D", "config": {"name": "conv3d_1", "trainable": true, "dtype": {"module": "keras", "class_name": "DTypePolicy", "config": {"name": "float32"}, "registered_name": null}, "filters": 16, "kernel_size": [3, 3, 3], "strides": [1, 1, 1], "padding": "same", "data_format": "channels_last", "dilation_rate": [1, 1, 1], "groups": 1, "activation": "linear", "use_bias": true, "kernel_initializer": {"module": "keras.initializers", "class_name": "GlorotUniform", "config": {"seed": null}, "registered_name": null}, "bias_initializer": {"module": "keras.initializers", "class_name": "Zeros", "config": {}, "registered_name": null}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}, {"class_name": "Activation", "config": {"name": "activation_1", "trainable": true, "dtype": {"module": "keras", "class_name": "DTypePolicy", "config": {"name": "float32"}, "registered_name": null}, "activation": "relu"}}, {"class_name": "MaxPooling3D", "config": {"name": "max_pooling3d", "trainable": true, "dtype": {"module": "keras", "class_name": "DTypePolicy", "config": {"name": "float32"}, "registered_name": null}, "pool_size": [3, 3, 3], "padding": "same", "strides": [3, 3, 3], "data_format": "channels_last"}}, {"class_name": "Dropout", "config": {"name": "dropout", "trainable": true, "dtype": {"module": "keras", "class_name": "DTypePolicy", "config": {"name": "float32"}, "registered_name": null}, "rate": 0.25, "seed": null, "noise_shape": null}}, {"class_name": "Conv3D", "config": {"name": "conv3d_2", "trainable": true, "dtype": {"module": "keras", "class_name": "DTypePolicy", "config": {"name": "float32"}, "registered_name": null}, "filters": 32, "kernel_size": [3, 3, 3], "strides": [1, 1, 1], "padding": "same", "data_format": "channels_last", "dilation_rate": [1, 1, 1], "groups": 1, "activation": "linear", "use_bias": true, "kernel_initializer": {"module": "keras.initializers", "class_name": "GlorotUniform", "config": {"seed": null}, "registered_name": null}, "bias_initializer": {"module": "keras.initializers", "class_name": "Zeros", "config": {}, "registered_name": null}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}, {"class_name": "Activation", "config": {"name": "activation_2", "trainable": true, "dtype": {"module": "keras", "class_name": "DTypePolicy", "config": {"name": "float32"}, "registered_name": null}, "activation": "relu"}}, {"class_name": "Conv3D", "config": {"name": "conv3d_3", "trainable": true, "dtype": {"module": "k ...
# training_config: {"loss": "categorical_crossentropy", "loss_weights": null, "metrics": ["categorical_accuracy"], "weighted_metrics": null, "run_eagerly": false, "steps_per_execution": 1, "jit_compile": false, "optimizer_config": {"class_name": "Adam", "config": {"name": "adam", "learning_rate": 0.0010000000474974513, "weight_decay": null, "clipnorm": null, "global_clipnorm": null, "clipvalue": null, "use_ema": false, "ema_momentum": 0.99, "ema_overwrite_frequency": null, "loss_scale_factor": null, "gradient_accumulation_steps": null, "beta_1": 0.9, "beta_2": 0.999, "epsilon": 1e-07, "amsgrad": false}}}

# %%
history_model1 = model_gen.c3d5(input_shape, num_classes)

# %%
print("Total Params:", history_model1.count_params())
history_model1 = history_model1.train_model(conv_3d1_model)
# Out:
# Total Params: 863877
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 2
#       1 print("Total Params:", history_model1.count_params())
# ----> 2 history_model1 = history_model1.train_model(conv_3d1_model)
#
# AttributeError: 'Sequential' object has no attribute 'train_model'

# %%
plot(history_model1)
